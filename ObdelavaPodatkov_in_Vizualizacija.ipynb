# %%
import pandas as pd
import matplotlib.pyplot as plt

data_2000 = pd.read_csv("podatki/improved/2000.csv", sep=";", thousands='.')
print(data_2000.columns.get_loc("Avtobusi"))
data_2000
# Out:
# 13
#     Kat. ceste Stev. ceste  Stev. odseka       Prometni odsek  Stac. zacetka  \
# 0           AC          A1            30  M.P.SENTILJ-SENTILJ              0
# 1           AC          A1            31    SENTILJ - PESNICA              0
# 2           AC          A1            34             SLIVNICA              0
# 3           AC          A1            35        SLIVNICA-FRAM              0
# 4           AC          A1            36     FRAM-SL.BISTRICA              0
# ..         ...         ...           ...                  ...            ...
# 869         RT         933          1193          BREG- LISCA              0
# 870         RT         933          1193     LISCA-JURKLOSTER           4650
# 871         RT         934          6838        SEZANA-LIPICA              0
# 872         RT         934          6840         LIPICA-LOKEV              0
# 873         RT         935          9042    FRAM-CESTNIK-AREH              0
#
# ...

# %%
data_2001 = pd.read_csv("podatki/improved/2001.csv", sep=";", thousands='.')
print(data_2001.columns.get_loc("Avtobusi"))
data_2001
# Out:
# 13
#     Kat. ceste Stev. ceste  Stev. odseka                  Prometni odsek  \
# 0           AC          A1            30              MP SENTILJ-SENTILJ
# 1           AC          A1            31               SENTILJ - PESNICA
# 2           AC          A1            66       MARIBOR(PTUJSKA)-SLIVNICA
# 3           AC          A1            34                        SLIVNICA
# 4           AC          A1            35                   SLIVNICA-FRAM
# ..         ...         ...           ...                             ...
# 917         RT         934          6840                    LIPICA-LOKEV
# 918         RT         935          9042               FRAM-CESTNIK-AREH
# 919         RT         936          1063                    COL-PREDMEJA
# 920         RT         937          8710        BRESTRNICA-GAJ-SV. JURIJ
# 921         RT         938          2503  CERMOSNJICE-KOMARNA V.-GRICICE
#
#      Stac. zacetka  Stac. Konca  Stevno mesto Tip pr. odseka Tip avt. stevca  \
# ...

# %%
data_2002 = pd.read_csv("podatki/improved/2002.csv", sep=";", thousands='.')
print(data_2002.columns.get_loc("Avtobusi"))
data_2002
# Out:
# 14
#     Kat. ceste Stev. ceste  Stev. odseka                  Prometni odsek  \
# 0           AC          A1            30              MP SENTILJ-SENTILJ
# 1           AC          A1            31               SENTILJ - PESNICA
# 2           AC          A1            66       MARIBOR(PTUJSKA)-SLIVNICA
# 3           AC          A1            34                        SLIVNICA
# 4           AC          A1            35                   SLIVNICA-FRAM
# ..         ...         ...           ...                             ...
# 923         RT         934          6840                    LIPICA-LOKEV
# 924         RT         935          9042               FRAM-CESTNIK-AREH
# 925         RT         936          1063                    COL-PREDMEJA
# 926         RT         937          8710        BRESTRNICA-GAJ-SV. JURIJ
# 927         RT         938          2503  CERMOSNJICE-KOMARNA V.-GRICICE
#
#      Stac. zacetka  Stac. konca  Stevno mesto Tip pr. odseka Tip avt. stevca  \
# ...

# %%
data_2003 = pd.read_csv("podatki/improved/2003.csv", sep=";", thousands='.')
print(data_2003.columns.get_loc("Avtobusi"))
data_2003
# Out:
# 14
#     Kat. ceste Stev. ceste  Stev. odseka                  Prometni odsek  \
# 0           AC          A1            30              MP SENTILJ-SENTILJ
# 1           AC          A1            31               SENTILJ - PESNICA
# 2           AC          A1            66       MARIBOR(PTUJSKA)-SLIVNICA
# 3           AC          A1            34                        SLIVNICA
# 4           AC          A1            35                   SLIVNICA-FRAM
# ..         ...         ...           ...                             ...
# 938         RT         934          6840                    LIPICA-LOKEV
# 939         RT         935          9042               FRAM-CESTNIK-AREH
# 940         RT         936          1063                    COL-PREDMEJA
# 941         RT         937          8710        BRESTRNICA-GAJ-SV. JURIJ
# 942         RT         938          2503  CERMOSNJICE-KOMARNA V.-GRICICE
#
#      Stac. zacetka  Stac. konca  Stevno mesto Tip pr. odseka Tip avt. stevca  \
# ...

# %%
data_2004 = pd.read_csv("podatki/improved/2004.csv", sep=";", thousands='.')
print(data_2004.columns.get_loc("Avtobusi"))
data_2004
# Out:
# 14
#     Kat. ceste Stev. ceste  Stev. odseka                  Prometni odsek  \
# 0           AC          A1            30              MP SENTILJ-SENTILJ
# 1           AC          A1            31               SENTILJ - PESNICA
# 2           AC          A1            66       MARIBOR(PTUJSKA)-SLIVNICA
# 3           AC          A1            34                        SLIVNICA
# 4           AC          A1            35                   SLIVNICA-FRAM
# ..         ...         ...           ...                             ...
# 940         RT         934          6840                    LIPICA-LOKEV
# 941         RT         935          9042               FRAM-CESTNIK-AREH
# 942         RT         936          1063                    COL-PREDMEJA
# 943         RT         937          8710        BRESTRNICA-GAJ-SV. JURIJ
# 944         RT         938          2503  CERMOSNJICE-KOMARNA V.-GRICICE
#
#      Stac. zacetka  Stac. konca  Stevno mesto Tip pr. odseka Tip avt. stevca  \
# ...

# %%
data_2005 = pd.read_csv("podatki/improved/2005.csv", sep=";", thousands='.')
print(data_2005.columns.get_loc("Avtobusi"))
data_2005
# Out:
# 14
#      Kat. ceste Stev. ceste  Stev. odseka                  Prometni odsek  \
# 0            AC          A1            30              MP SENTILJ-SENTILJ
# 1            AC          A1            31               SENTILJ - PESNICA
# 2            AC          A1            66              MB(PTUJSKA)-ROGOZA
# 3            AC          A1            66                 ROGOZA-SLIVNICA
# 4            AC          A1            34                        SLIVNICA
# ...         ...         ...           ...                             ...
# 1015         RT         934          6840                    LIPICA-LOKEV
# 1016         RT         935          9042               FRAM-CESTNIK-AREH
# 1017         RT         936          1063                    COL-PREDMEJA
# 1018         RT         937          8710        BRESTRNICA-GAJ-SV. JURIJ
# 1019         RT         938          2503  CERMOSNJICE-KOMARNA V.-GRICICE
#
# ...

# %%
data_2006 = pd.read_csv("podatki/improved/2006.csv", sep=";", thousands='.')
print(data_2006.columns.get_loc("Avtobusi"))
data_2006
# Out:
# 14
#      Kat. ceste Stev. ceste  Stev. odseka                  Prometni odsek  \
# 0            AC          A1            30              MP SENTILJ-SENTILJ
# 1            AC          A1            31               SENTILJ - PESNICA
# 2            AC          A1            66              MB(PTUJSKA)-ROGOZA
# 3            AC          A1            66                 ROGOZA-SLIVNICA
# 4            AC          A1            34                        SLIVNICA
# ...         ...         ...           ...                             ...
# 1041         RT         934          6840                    LIPICA-LOKEV
# 1042         RT         935          9042               FRAM-CESTNIK-AREH
# 1043         RT         936          1063                    COL-PREDMEJA
# 1044         RT         937          8710        BRESTRNICA-GAJ-SV. JURIJ
# 1045         RT         938          2503  CERMOSNJICE-KOMARNA V.-GRICICE
#
# ...

# %%
data_2007 = pd.read_csv("podatki/improved/2007.csv", sep=";", thousands='.')
print(data_2007.columns.get_loc("Avtobusi"))
data_2007
# Out:
# 14
#      Kat. ceste Stev. ceste  Stev. odseka                  Prometni odsek  \
# 0            AC          A1            30  MP SENTILJ-POCIVALISCE SENTILJ
# 1            AC          A1            30     POCIVALISCE SENTILJ-SENTILJ
# 2            AC          A1           128               PRIKLJ.SENTILJ-MP
# 3            AC          A1            31               SENTILJ - PESNICA
# 4            AC          A1            66              MB(PTUJSKA)-ROGOZA
# ...         ...         ...           ...                             ...
# 1075         RT         935          9042               FRAM-CESTNIK-AREH
# 1076         RT         936          1063                    COL-PREDMEJA
# 1077         RT         937          8710        BRESTRNICA-GAJ-SV. JURIJ
# 1078         RT         938          2503  CERMOSNJICE-KOMARNA V.-GRICICE
# 1079         RT         939          3815                        PREDDVOR
#
# ...

# %%
data_2008 = pd.read_csv("podatki/improved/2008.csv", sep=";", thousands='.')
print(data_2008.columns.get_loc("Avtobusi"))
data_2008
# Out:
# 13
#      Kat. ceste Stev. ceste  Stev. odseka                  Prometni odsek  \
# 0            AC          A1            30  MP SENTILJ-POCIVALISCE SENTILJ
# 1            AC          A1            30     POCIVALISCE SENTILJ-SENTILJ
# 2            AC          A1           128               PRIKLJ.SENTILJ-MP
# 3            AC          A1            31                SENTILJ- PESNICA
# 4            AC          A1            65               PESNICA-DRAGUCOVA
# ...         ...         ...           ...                             ...
# 1126         RT         940          1018                   MATAVUN-VREME
# 1127         RT         940          3214                 ZAVRHEK-ARTVIZE
# 1128         RT         940          3214                ARTVIZE-PREGARJE
# 1129         RT         940          3213                 PREGARJE-HARIJE
# 1130         RT         941          1541                   VIDEM-RADENCI
#
# ...

# %%
data_2009 = pd.read_csv("podatki/improved/2009.csv", sep=";", thousands='.')
print(data_2009.columns.get_loc("Avtobusi"))
data_2009
# Out:
# 13
#      Kat. ceste Stev. ceste  Stev. odseka                    Prometni odsek  \
# 0            AC          A1            30  MP SENTILJ - POCIVALISCE SENTILJ
# 1            AC          A1            30     POCIVALISCE SENTILJ - SENTILJ
# 2            AC          A1           128               PRIKLJ.SENTILJ - MP
# 3            AC          A1            31               SENTILJ  -  PESNICA
# 4            AC          A1            65               PESNICA - DRAGUCOVA
# ...         ...         ...           ...                               ...
# 1136         RT         940          1018                   MATAVUN - VREME
# 1137         RT         940          3214                ZAVRHEK - ARTVIZE
# 1138         RT         940          3214                ARTVIZE - PREGARJE
# 1139         RT         940          3213                 PREGARJE - HARIJE
# 1140         RT         941          1541                   VIDEM - RADENCI
#
# ...

# %%
data_2010 = pd.read_csv("podatki/improved/2010.csv", sep=";", thousands='.')
print(data_2010.columns.get_loc("Avtobusi"))
data_2010.sort_values(by='Avtobusi',ascending=False)
# Out:
# 12
#      Kat. ceste Stev. ceste  Stev. odseka                 Prometni odsek  \
# 244          G1           8           213      LJ(SENTVID  -  OBVOZNICA)
# 52           AC          A1            52            BREZOVICA - VRHNIKA
# 57           AC          A1            54                 LOGATEC - UNEC
# 36           AC          A1            44              LUKOVICA - KRTINA
# 35           AC          A1            44           BLAGOVICA - LUKOVICA
# ...         ...         ...           ...                            ...
# 1078         R3         753          1544                VOLCE - SOLARJI
# 1011         R3         718          5619                      FIKSINCI
# 889          R3         662          5407         RADOVICI - MP BOZAKOVO
# 779          R3         616          1056            GORJANSKO - KLARICI
# 873          R3         656          3650  DRAGARJI-GOZ. CESTA(OSILNICA)
#
#       Stac. zacetka  Stac. konca Stevno mesto   Ime stevnega mesta Tip stetja  \
# ...

# %%
data_2011 = pd.read_csv("podatki/improved/2011.csv", sep=";", thousands='.')
data_2011['Motorji'] = data_2011['Motorji'].astype('Int64')
print(data_2011.columns.get_loc("Avtobusi"))
data_2011
# Out:
# 12
#      Kat. ceste Stev. ceste  Stev. odseka                    Prometni odsek  \
# 0            AC          A1            30  MP SENTILJ - POCIVALISCE SENTILJ
# 1            AC          A1            30     POCIVALISCE SENTILJ - SENTILJ
# 2            AC          A1           128               PRIKLJ.SENTILJ - MP
# 3            AC          A1            31               SENTILJ  -  PESNICA
# 4            AC          A1            65               PESNICA - DRAGUCOVA
# ...         ...         ...           ...                               ...
# 1152         RT         940          1018                   MATAVUN-ZAVRHEK
# 1153         RT         940          3214                 ZAVRHEK - ARTVIZE
# 1154         RT         940          3214                ARTVIZE - PREGARJE
# 1155         RT         940          3213                 PREGARJE - HARIJE
# 1156         RT         941          1541                  GRABONOS-RADENCI
#
# ...

# %%
data_2012 = pd.read_csv("podatki/improved/2012.csv", sep=";", thousands='.')
data_2012 = data_2012.iloc[: , :-1]
print(data_2012.columns.get_loc("Avtobusi"))
data_2012
# Out:
# 12
#      Kat. ceste Stev. ceste  Stev. odseka                    Prometni odsek  \
# 0            AC          A1            30  MP SENTILJ - POCIVALISCE SENTILJ
# 1            AC          A1            30     POCIVALISCE SENTILJ - SENTILJ
# 2            AC          A1           128               PRIKLJ.SENTILJ - MP
# 3            AC          A1            31               SENTILJ  -  PESNICA
# 4            AC          A1            65               PESNICA - DRAGUCOVA
# ...         ...         ...           ...                               ...
# 1167         RT         940          1018                   MATAVUN - VREME
# 1168         RT         940          3214                ZAVRHEK - ARTVIZE-
# 1169         RT         940          3214                ARTVIZE - PREGARJE
# 1170         RT         940          3213                 PREGARJE - HARIJE
# 1171         RT         941          1541                GRABONOS - RADENCI
#
# ...

# %%
data_2013 = pd.read_csv("podatki/improved/2013.csv", sep=";", thousands='.')
print(data_2013.columns.get_loc("Avtobusi"))
data_2013
# Out:
# 12
#      Kat. ceste Stev. ceste  Stev. odseka                    Prometni odsek  \
# 0            AC          A1            30  MP SENTILJ - POCIVALISCE SENTILJ
# 1            AC          A1            30     POCIVALISCE SENTILJ - SENTILJ
# 2            AC          A1           128       PRIKLJ.SENTILJ - MP SENTILJ
# 3            AC          A1            31               SENTILJ  -  PESNICA
# 4            AC          A1            65               PESNICA - DRAGUCOVA
# ...         ...         ...           ...                               ...
# 1174         RT         940          1018                   MATAVUN - VREME
# 1175         RT         940          3214                ZAVRHEK - ARTVIZE-
# 1176         RT         940          3214                ARTVIZE - PREGARJE
# 1177         RT         940          3213                 PREGARJE - HARIJE
# 1178         RT         941          1541                GRABONOS - RADENCI
#
# ...

# %%
data_2014 = pd.read_csv("podatki/improved/2014.csv", sep=";", thousands='.')
data_2014.sort_values(by='Avtobusi',ascending=False)
# Out:
#     Kat. ceste Stev. ceste  Stev. odseka             Prometni odsek  \
# 53          AC          A1            52        BREZOVICA - VRHNIKA
# 252         G1           8           213  LJ(SENTVID  -  OBVOZNICA)
# 56          AC          A1            53          VRHNIKA - LOGATEC
# 52          AC          A1            51    LJ(KOZARJE) - BREZOVICA
# 58          AC          A1            54             LOGATEC - UNEC
# ..         ...         ...           ...                        ...
# 776         R3         605          5702            SOLARJI - LIVEK
# 777         R3         605          1545       SOLARJI-MEJA ITALIJA
# 782         R3         608          1065            LOKVE - CEPOVAN
# 783         R3         608          1068      CEPOVAN - DOL.TREBUSA
# 938         R3         676          2216           KAPELE - RAKOVEC
#
#      Stac. zacetka  Stac. konca  Stevno mesto   Ime stevnega mesta Tip stetja  \
# ...

# %%
data_2015 = pd.read_csv("podatki/improved/2015.csv", sep=";", thousands='.')
#print(data_2015['Avtobusi'].isnull().values.any())
#data_2015.sort_values(by='Avtobusi',ascending=False)
data_2015['Avtobusi'] = data_2015['Avtobusi'].astype('Int64')
data_2015.sort_values(by='Avtobusi',ascending=False)
# Out:
#     Kat. ceste Stev. ceste  Stev. odseka                      Prometni odsek  \
# 53          AC          A1            52                 BREZOVICA - VRHNIKA
# 251         G1           8           213           LJ(SENTVID  -  OBVOZNICA)
# 56          AC          A1            53                   VRHNIKA - LOGATEC
# 52          AC          A1            51            LJ (KOZARJE) - BREZOVICA
# 58          AC          A1            54                      LOGATEC - UNEC
# ..         ...         ...           ...                                 ...
# 902         R3         656          3650  GOZDNA CESTA (OSILNICA) - OSILNICA
# 903         R3         657          3610          PETRINA - GRIVAC-MIRTOVICI
# 834         R3         631          3223                    STAROD - MEJA RH
# 192         HC          H7           815                      A5 - DOLGA VAS
# 548         R2         409           305            RAVBARKOMANDA - PO(R913)
#
# ...

# %%
data_2016 = pd.read_csv("podatki/improved/2016.csv", sep=";", thousands='.')
data_2016
# Out:
#      Kat. ceste Stev. ceste  Stev. odseka                    Prometni odsek  \
# 0            AC          A1            30  MP SENTILJ - POCIVALISCE SENTILJ
# 1            AC          A1            30     POCIVALISCE SENTILJ - SENTILJ
# 2            AC          A1           128       PRIKLJ.SENTILJ - MP SENTILJ
# 3            AC          A1            31               SENTILJ  -  PESNICA
# 4            AC          A1            65               PESNICA - DRAGUCOVA
# ...         ...         ...           ...                               ...
# 1174         RT         940          1018                   MATAVUN - VREME
# 1175         RT         940          3214                 ZAVRHEK - ARTVIZE
# 1176         RT         940          3214                ARTVIZE - PREGARJE
# 1177         RT         940          3213                 PREGARJE - HARIJE
# 1178         RT         941          1541                GRABONOS - RADENCI
#
# ...

# %%
data_2017 = pd.read_csv("podatki/improved/2017.csv", sep=";", thousands='.')
data_2017
# Out:
#      Kat. ceste Stev. ceste  Stev. odseka                    Prometni odsek  \
# 0            AC          A1            30  MP SENTILJ - POCIVALISCE SENTILJ
# 1            AC          A1            30     POCIVALISCE SENTILJ - SENTILJ
# 2            AC          A1           128       PRIKLJ.SENTILJ - MP SENTILJ
# 3            AC          A1            31               SENTILJ  -  PESNICA
# 4            AC          A1            65               PESNICA - DRAGUCOVA
# ...         ...         ...           ...                               ...
# 1173         RT         940          1018                   MATAVUN - VREME
# 1174         RT         940          3214                 ZAVRHEK - ARTVIZE
# 1175         RT         940          3214                ARTVIZE - PREGARJE
# 1176         RT         940          3213                 PREGARJE - HARIJE
# 1177         RT         941          1541                GRABONOS - RADENCI
#
# ...

# %%
data_2018 = pd.read_csv("podatki/improved/2018.csv", sep=";", thousands='.')
data_2018 = data_2018.iloc[: , :-3]
data_2018
# Out:
#      Kat. ceste Stev. ceste  Stev. odseka                    Prometni odsek  \
# 0            AC          A1            30  MP SENTILJ - POCIVALISCE SENTILJ
# 1            AC          A1            30     POCIVALISCE SENTILJ - SENTILJ
# 2            AC          A1           128       PRIKLJ.SENTILJ - MP SENTILJ
# 3            AC          A1            31               SENTILJ  -  PESNICA
# 4            AC          A1            65               PESNICA - DRAGUCOVA
# ...         ...         ...           ...                               ...
# 1185         RT         940          1018                   MATAVUN - VREME
# 1186         RT         940          3214                 ZAVRHEK - ARTVIZE
# 1187         RT         940          3214                ARTVIZE - PREGARJE
# 1188         RT         940          3213                 PREGARJE - HARIJE
# 1189         RT         941          1541                GRABONOS - RADENCI
#
# ...

# %%
data_2019 = pd.read_csv("podatki/improved/2019.csv", sep=";", thousands='.')
data_2019
# Out:
#      Kat. ceste Stev. ceste  Stev. odseka                    Prometni odsek  \
# 0            AC          A1            30  MP SENTILJ - POCIVALISCE SENTILJ
# 1            AC          A1            30     POCIVALISCE SENTILJ - SENTILJ
# 2            AC          A1           128       PRIKLJ.SENTILJ - MP SENTILJ
# 3            AC          A1            31               SENTILJ  -  PESNICA
# 4            AC          A1            65               PESNICA - DRAGUCOVA
# ...         ...         ...           ...                               ...
# 1185         RT         940          1018                   MATAVUN - VREME
# 1186         RT         940          3214                 ZAVRHEK - ARTVIZE
# 1187         RT         940          3214                ARTVIZE - PREGARJE
# 1188         RT         940          3213                 PREGARJE - HARIJE
# 1189         RT         941          1541                GRABONOS - RADENCI
#
# ...

# %%
Numpy2019 = data_2019.to_numpy()
Numpy2019
# Out:
# array([['AC', 'A1', 30, ..., 2582, 2579, 'PLDP'],
#        ['AC', 'A1', 30, ..., 2567, 2563, 'PLDP'],
#        ['AC', 'A1', 128, ..., 25, 26, 'PLDP'],
#        ...,
#        ['RT', '940', 3214, ..., 1, 2, 'PLDP'],
#        ['RT', '940', 3213, ..., 1, 4, 'PLDP'],
#        ['RT', '941', 1541, ..., 2, 23, 'PLDP']], dtype=object)

# %%
"""Test pull requesta"""
# Out:
# 'Test pull requesta'

# %% [markdown]
# ## Prikaz števila avtobusov po letih

# %% [markdown]
# Združitev avtobusov v tabelo (po indeksih so števila urejena po letih - 0 - 2000, 1 - 2001, 2 - 2002, 3 - 2003...)

# %%
avtobusiSum = []
avtobusiSum.append(data_2000['Avtobusi'].sum())
avtobusiSum.append(data_2001['Avtobusi'].sum())
avtobusiSum.append(data_2002['Avtobusi'].sum())
avtobusiSum.append(data_2003['Avtobusi'].sum())
avtobusiSum.append(data_2004['Avtobusi'].sum())
avtobusiSum.append(data_2005['Avtobusi'].sum())
avtobusiSum.append(data_2006['Avtobusi'].sum())
avtobusiSum.append(data_2007['Avtobusi'].sum())
avtobusiSum.append(data_2008['Avtobusi'].sum())
avtobusiSum.append(data_2009['Avtobusi'].sum())
avtobusiSum.append(data_2010['Avtobusi'].sum())
avtobusiSum.append(data_2011['Avtobusi'].sum())
avtobusiSum.append(data_2012['Avtobusi'].sum())
avtobusiSum.append(data_2013['Avtobusi'].sum())
avtobusiSum.append(data_2014['Avtobusi'].sum())
avtobusiSum.append(int(data_2015['Avtobusi'].sum()))
avtobusiSum.append(data_2016['Avtobusi'].sum())
avtobusiSum.append(data_2017['Avtobusi'].sum())
avtobusiSum.append(data_2018['Avtobusi'].sum())
avtobusiSum.append(data_2019['Avtobusi'].sum())
avtobusiSum
# Out:
# [44437,
#  44618,
#  44887,
#  46423,
#  47044,
#  48737,
#  51023,
#  54127,
#  55634,
#  55404,
#  56290,
#  56618,
#  56307,
#  57768,
#  58685,
#  60612,
#  61162,
#  62850,
#  66036,
#  68196]

# %%
import numpy as np
leta = np.arange(2000,2020,1)
leta
# Out:
# array([2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010,
#        2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019])

# %%
fig, axes = plt.subplots(figsize=(12, 3), dpi=200)

tickRange = np.arange(2000,2020,1)
axes.set_xticks(tickRange)

leta = np.array(leta)
axes.bar(leta, avtobusiSum, width=0.5, alpha=0.5)
axes.set_title("Število avtobusov po letih")
# Out:
# Text(0.5, 1.0, 'Število avtobusov po letih')

# %% [markdown]
# ## Prikaz števila osebnih vozil po letih

# %%
osebnaVozilaSum = []
osebnaVozilaSum.append(data_2000['Osebna vozila'].sum())
osebnaVozilaSum.append(data_2001['Osebna vozila'].sum())
osebnaVozilaSum.append(data_2002['Osebna vozila'].sum())
osebnaVozilaSum.append(data_2003['Osebna vozila'].sum())
osebnaVozilaSum.append(data_2004['Osebna vozila'].sum())
osebnaVozilaSum.append(data_2005['Osebna vozila'].sum())
osebnaVozilaSum.append(data_2006['Osebna vozila'].sum())
osebnaVozilaSum.append(data_2007['Osebna vozila'].sum())
osebnaVozilaSum.append(data_2008['Osebna vozila'].sum())
osebnaVozilaSum.append(data_2009['Osebna vozila'].sum())
osebnaVozilaSum.append(data_2010['Osebna vozila'].sum())
osebnaVozilaSum.append(data_2011['Osebna vozila'].sum())
osebnaVozilaSum.append(data_2012['Osebna vozila'].sum())
osebnaVozilaSum.append(data_2013['Osebna vozila'].sum())
osebnaVozilaSum.append(data_2014['Osebna vozila'].sum())
osebnaVozilaSum.append(int(data_2015['Osebna vozila'].sum()))
osebnaVozilaSum.append(data_2016['Osebna vozila'].sum())
osebnaVozilaSum.append(data_2017['Osebna vozila'].sum())
osebnaVozilaSum.append(data_2018['Osebna vozila'].sum())
osebnaVozilaSum.append(data_2019['Osebna vozila'].sum())
osebnaVozilaSum
# Out:
# [4436930,
#  4820448,
#  5011732,
#  5150132,
#  5425771,
#  6089184,
#  6441959,
#  6910985,
#  7128262,
#  7388965,
#  7417375,
#  7616667,
#  7437178,
#  7567018,
#  7648813,
#  7817459,
#  8044783,
#  8246160,
#  8713908,
#  8909769]

# %%
fig, axes = plt.subplots(figsize=(12, 3), dpi=200)

tickRange = np.arange(2000,2020,1)
axes.set_xticks(tickRange)

leta = np.array(leta)
axes.bar(leta, osebnaVozilaSum, width=0.5, alpha=0.5)
axes.set_title("Število osebnih vozil po letih")
# Out:
# Text(0.5, 1.0, 'Število osebnih vozil po letih')

# %% [markdown]
# ## Prikaz števila lahkih tovornih vozil po letih

# %% [markdown]
# Združitev lahkih tovornih vozil v tabelo. Od 2005 so za lahka tovorna vozila šteta vozila pod 3,5t, pred tem pa pod 3t. Vse sem upošteval skupaj, ker gre za isto kategorijo vozil.

# %%
L_tovorna = []
L_tovorna.append(int(round(data_2000['Lahka tov. < 3t'].sum())))
L_tovorna.append(int(round(data_2001['Lahka tov. < 3t'].sum())))
L_tovorna.append(int(round(data_2002['Lahka tov. < 3t'].sum())))
L_tovorna.append(int(round(data_2003['Lahka tov. < 3t'].sum())))
L_tovorna.append(int(round(data_2004['Lahka tov. < 3t'].sum())))
L_tovorna.append(int(round(data_2005['Lah. tov. < 3,5t'].sum())))
L_tovorna.append(int(round(data_2006['Lah. tov. < 3,5t'].sum())))
L_tovorna.append(int(round(data_2007['Lah. tov. < 3,5t'].sum())))
L_tovorna.append(int(round(data_2008['Lah. tov. < 3,5t'].sum())))
L_tovorna.append(int(round(data_2009['Lah. tov. < 3,5t'].sum())))
L_tovorna.append(int(round(data_2010['Lah. tov. < 3,5t'].sum())))
L_tovorna.append(int(round(data_2011['Lah. tov. < 3,5t'].sum())))
L_tovorna.append(int(round(data_2012['Lah. tov. < 3,5t'].sum())))
L_tovorna.append(int(round(data_2013['Lah. tov. < 3,5t'].sum())))
L_tovorna.append(int(round(data_2014['Lah. tov. < 3,5t'].sum())))
L_tovorna.append(int(round(data_2015['Lah. tov < 3,5t'].sum())))
L_tovorna.append(int(round(data_2016['Lah. tov < 3,5t'].sum())))
L_tovorna.append(int(round(data_2017['Lah. tov.  < 3,5t'].sum())))
L_tovorna.append(int(round(data_2018['Lah. tov.  < 3,5t'].sum())))
L_tovorna.append(int(round(data_2019['Lah. tov.  < 3,5t'].sum())))
L_tovorna
# Out:
# [227075,
#  249901,
#  265089,
#  294666,
#  322343,
#  359898,
#  406270,
#  477819,
#  536362,
#  566413,
#  621740,
#  636193,
#  641749,
#  670634,
#  692546,
#  723384,
#  755822,
#  794815,
#  874895,
#  912763]

# %%
fig, axes = plt.subplots(figsize=(12, 3), dpi=200)

tickRange = np.arange(2000,2020,1)
axes.set_xticks(tickRange)

leta = np.array(leta)
axes.bar(leta, L_tovorna, width=0.5, alpha=0.5)
axes.set_title("Število lahkih tovornih vozil po letih")
# Out:
# Text(0.5, 1.0, 'Število lahkih tovornih vozil po letih')

# %% [markdown]
# ## Prikaz števila srednjih tovornjakov po letih

# %% [markdown]
# Združitev srednjih tovornjakov v tabelo:

# %%
SR_tovorna = []
SR_tovorna.append(int(round(data_2000['Sr. tov.  3-7t'].sum())))
SR_tovorna.append(int(round(data_2001['Sr. tov.  3-7t'].sum())))
SR_tovorna.append(int(round(data_2002['Sr. tov.  3-7t'].sum())))
SR_tovorna.append(int(round(data_2003['Sr. tov.  3-7t'].sum())))
SR_tovorna.append(int(round(data_2004['Sr. tov.  3-7t'].sum())))
SR_tovorna.append(int(round(data_2005['Sr. tov.  3,5-7t'].sum())))
SR_tovorna.append(int(round(data_2006['Sr. tov.  3,5-7t'].sum())))
SR_tovorna.append(int(round(data_2007['Sr. tov.  3,5-7t'].sum())))
SR_tovorna.append(int(round(data_2008['Sr. tov.  3,5-7t'].sum())))
SR_tovorna.append(int(round(data_2009['Sr. tov.  3,5-7t'].sum())))
SR_tovorna.append(int(round(data_2010['Sr. tov.  3,5-7t'].sum())))
SR_tovorna.append(int(round(data_2011['Sr. tov.  3,5-7t'].sum())))
SR_tovorna.append(int(round(data_2012['Sr. tov.  3,5-7t'].sum())))
SR_tovorna.append(int(round(data_2013['Sr. tov.  3,5-7t'].sum())))
SR_tovorna.append(int(round(data_2014['Sr. tov.  3,5-7t'].sum())))
SR_tovorna.append(int(round(data_2015['Sr. tov  3,5-7t'].sum())))
SR_tovorna.append(int(round(data_2016['Sr. tov  3,5-7t'].sum())))
SR_tovorna.append(int(round(data_2017['Sr. tov.  3,5-7t'].sum())))
SR_tovorna.append(int(round(data_2018['Sr. tov.  3,5-7t'].sum())))
SR_tovorna.append(int(round(data_2019['Sr. tov.  3,5-7t'].sum())))
SR_tovorna
# Out:
# [137726,
#  123171,
#  122547,
#  112278,
#  112534,
#  114711,
#  116676,
#  120226,
#  122560,
#  116994,
#  123359,
#  118874,
#  111875,
#  112479,
#  113823,
#  113856,
#  114103,
#  116793,
#  119908,
#  118372]

# %%
fig, axes = plt.subplots(figsize=(12, 3), dpi=200)

tickRange = np.arange(2000,2020,1)
axes.set_xticks(tickRange)

leta = np.array(leta)
axes.bar(leta, SR_tovorna, width=0.5, alpha=0.5)
axes.set_title("Število srednjih tovornjakov po letih")
# Out:
# Text(0.5, 1.0, 'Število srednjih tovornjakov po letih')

# %% [markdown]
# ## Prikaz števila težkih tovornjakov po letih

# %% [markdown]
# Združitev težkih tovornjakov v tabelo:

# %%
TE_tovorna = []
TE_tovorna.append(int(round(data_2000['Tez. tov. nad 7t'].sum())))
TE_tovorna.append(int(round(data_2001['Tez. tov. nad 7t'].sum())))
TE_tovorna.append(int(round(data_2002['Tez. tov. nad 7t'].sum())))
TE_tovorna.append(int(round(data_2003['Tez. tov. nad 7t'].sum())))
TE_tovorna.append(int(round(data_2004['Tez. tov. nad 7t'].sum())))
TE_tovorna.append(int(round(data_2005['Tez. tov. nad 7t'].sum())))
TE_tovorna.append(int(round(data_2006['Tez. tov. nad 7t'].sum())))
TE_tovorna.append(int(round(data_2007['Tez. tov. nad 7t'].sum())))
TE_tovorna.append(int(round(data_2008['Tez. tov. nad 7t'].sum())))
TE_tovorna.append(int(round(data_2009['Tez. tov. nad 7t'].sum())))
TE_tovorna.append(int(round(data_2010['Tez. tov. nad 7t'].sum())))
TE_tovorna.append(int(round(data_2011['Tez. tov. nad 7t'].sum())))
TE_tovorna.append(int(round(data_2012['Tez. tov. nad 7t'].sum())))
TE_tovorna.append(int(round(data_2013['Tez. tov. nad 7t'].sum())))
TE_tovorna.append(int(round(data_2014['Tez. tov. nad 7t'].sum())))
TE_tovorna.append(int(round(data_2015['Tez. tov. nad 7t'].sum())))
TE_tovorna.append(int(round(data_2016['Tez. tov. nad 7t'].sum())))
TE_tovorna.append(int(round(data_2017['Tez. tov. nad 7t'].sum())))
TE_tovorna.append(int(round(data_2018['Tez. tov. nad 7t'].sum())))
TE_tovorna.append(int(round(data_2019['Tez. tov. nad 7t'].sum())))
TE_tovorna
# Out:
# [56320,
#  61605,
#  66832,
#  76464,
#  83735,
#  97458,
#  108224,
#  124787,
#  130200,
#  116698,
#  100406,
#  88235,
#  79166,
#  76316,
#  76586,
#  77174,
#  76222,
#  76274,
#  79121,
#  80642]

# %%
fig, axes = plt.subplots(figsize=(12, 3), dpi=200)

tickRange = np.arange(2000,2020,1)
axes.set_xticks(tickRange)

leta = np.array(leta)
axes.bar(leta, TE_tovorna, width=0.5, alpha=0.5)
axes.set_title("Število težkih tovornjakov po letih")
# Out:
# Text(0.5, 1.0, 'Število težkih tovornjakov po letih')

# %%
fig, axes = plt.subplots(figsize=(12, 3), dpi=200)

tickRange = np.arange(2000,2020,1)
axes.set_xticks(tickRange)

leta = np.array(leta)

avtobusiMultyplyed = [element * 100 for element in avtobusiSum]

axes.bar(leta, avtobusiMultyplyed, width=0.5, alpha=0.5,color = 'blue')
axes.bar(leta, osebnaVozilaSum, width=0.5, alpha=0.1,color='red')
axes.set_title("Število avtobusov in osebnih vozil po letih na istem grafu. \nAvtobusi so pomnoženi vsako leto s 100.")
# Out:
# Text(0.5, 1.0, 'Število avtobusov in osebnih vozil po letih na istem grafu. \nAvtobusi so pomnoženi vsako leto s 100.')

# %% [markdown]
# Opazimo, da število avtobusov in osebnih vozil narašča z relativno enako hitrostjo (je pa osebnih vozil pribljižno 100-krat več kot avtobusov).

# %% [markdown]
# Še linegraph, za drugačen pogled na absolutno razliko med številom vozil po letih

# %%
fig, axes = plt.subplots(figsize=(12, 3), dpi=200)

tickRange = np.arange(2000,2020,1)
axes.set_xticks(tickRange)

leta = np.array(leta)

avtobusiMultyplyed = [element * 100 for element in avtobusiSum]

axes.plot(leta, avtobusiMultyplyed, alpha=0.5,color = 'purple')
axes.plot(leta, osebnaVozilaSum, alpha=0.5,color='orange')
axes.set_title("Število avtobusov in osebnih vozil po letih na istem grafu. \nAvtobusi so pomnoženi vsako leto s 100.")
# Out:
# Text(0.5, 1.0, 'Število avtobusov in osebnih vozil po letih na istem grafu. \nAvtobusi so pomnoženi vsako leto s 100.')

# %% [markdown]
# ## Prikaz števila tovornih vozil s prikolico po letih

# %% [markdown]
# Združitev tovornih vozil v tabelo:

# %%
tov_prikolica = []
tov_prikolica.append(int(round(data_2000['Tov. s prik.'].sum())))
tov_prikolica.append(int(round(data_2001['Tov. s prik.'].sum())))
tov_prikolica.append(int(round(data_2002['Tov. s prik.'].sum())))
tov_prikolica.append(int(round(data_2003['Tov. s prik.'].sum())))
tov_prikolica.append(int(round(data_2004['Tov. s prik.'].sum())))
tov_prikolica.append(int(round(data_2005['Tov. s prik.'].sum())))
tov_prikolica.append(int(round(data_2006['Tov. s prik.'].sum())))
tov_prikolica.append(int(round(data_2007['Tov. s prik.'].sum())))
tov_prikolica.append(int(round(data_2008['Tov. s prik.'].sum())))
tov_prikolica.append(int(round(data_2009['Tov. s prik.'].sum())))
tov_prikolica.append(int(round(data_2010['Tov. s prik.'].sum())))
tov_prikolica.append(int(round(data_2011['Tov. s prik.'].sum())))
tov_prikolica.append(int(round(data_2012['Tov. s prik.'].sum())))
tov_prikolica.append(int(round(data_2013['Tov. s prik.'].sum())))
tov_prikolica.append(int(round(data_2014['Tov. s prik.'].sum())))
tov_prikolica.append(int(round(data_2015['Tov. s prik.'].sum())))
tov_prikolica.append(int(round(data_2016['Tov. s prik.'].sum())))
tov_prikolica.append(int(round(data_2017['Tov. s prik.'].sum())))
tov_prikolica.append(int(round(data_2018['Tov. s prik.'].sum())))
tov_prikolica.append(int(round(data_2019['Tov. s prik.'].sum())))
tov_prikolica
# Out:
# [134603,
#  153745,
#  164938,
#  186000,
#  229784,
#  307458,
#  358138,
#  437503,
#  156649,
#  120448,
#  100751,
#  94671,
#  88588,
#  88263,
#  86869,
#  90331,
#  93026,
#  95697,
#  103355,
#  105337]

# %%
fig, axes = plt.subplots(figsize=(12, 3), dpi=200)

tickRange = np.arange(2000,2020,1)
axes.set_xticks(tickRange)

leta = np.array(leta)
axes.bar(leta, tov_prikolica, width=0.5, alpha=0.5)
axes.bar(leta, TE_tovorna, width=0.5, alpha=0.5, color="red")
axes.set_title("Število tovornih vozil s prikolico po letih skupaj s težkimi tovornjaki.")
# Out:
# Text(0.5, 1.0, 'Število tovornih vozil s prikolico po letih skupaj s težkimi tovornjaki.')

# %% [markdown]
# Grafa tovornih vozil s prikolico in težkih tovornjakov po letih na skupni sliki. Lepo se vidi da je število obojih do gospodarske krize leta 2008 naraščalo (tovornih vozil s prikolico je do tega leta do 3-krat več na leto kot težkih tovornjakov). Od 2008 naprej je število tovornih vozil s prikolico strmo padlo, število težkih tovornjakov pa malo manj strmo, a še vseeno. Okoli leta 2013 je število obeh vrst vozil začelo ponovno naraščati.

# %% [markdown]
# Še linegraph, za drugačen pogled na absolutno razliko med številom vozil po letih

# %%
fig, axes = plt.subplots(figsize=(12, 3), dpi=200)

tickRange = np.arange(2000,2020,1)
axes.set_xticks(tickRange)

leta = np.array(leta)

avtobusiMultyplyed = [element * 100 for element in avtobusiSum]

axes.plot(leta, tov_prikolica, alpha=0.5)
axes.plot(leta, TE_tovorna, alpha=0.5,color='red')
axes.set_title("Število tovornih vozil s prikolico po letih skupaj s težkimi tovornjaki.")
# Out:
# Text(0.5, 1.0, 'Število tovornih vozil s prikolico po letih skupaj s težkimi tovornjaki.')

# %% [markdown]
# ##Ugotavljanje kateri stolpci so skupni vsem dataframe-om.

# %%
d = [list(data_2000.columns),list(data_2001.columns),list(data_2002.columns),list(data_2003.columns),
     list(data_2004.columns),list(data_2005.columns),list(data_2006.columns),list(data_2007.columns),
     list(data_2008.columns),list(data_2009.columns),list(data_2010.columns),list(data_2011.columns),
     list(data_2012.columns),list(data_2013.columns),list(data_2014.columns),list(data_2015.columns),
     list(data_2016.columns),list(data_2017.columns),list(data_2018.columns),list(data_2019.columns)]

skupni_atributi = set.intersection(*[set(x) for x in d])  
skupni_atributi
# Out:
# {'Avtobusi',
#  'Ime stevnega mesta',
#  'Kat. ceste',
#  'Motorji',
#  'Osebna vozila',
#  'Prometni odsek',
#  'Stac. zacetka',
#  'Stev. ceste',
#  'Stev. odseka',
#  'Stevno mesto',
#  'Tez. tov. nad 7t',
#  'Tov. s prik.',
#  'Vsa vozila (PLDP)'}

# %%
s = []
s.append(data_2000)
s.append(data_2001)
s.append(data_2002)
s.append(data_2003)
s.append(data_2004)
s.append(data_2005)
s.append(data_2006)
s.append(data_2007)
s.append(data_2008)
s.append(data_2009)
s.append(data_2010)
s.append(data_2011)
s.append(data_2012)
s.append(data_2013)
s.append(data_2014)
s.append(data_2015)
s.append(data_2016)
s.append(data_2017)
s.append(data_2018)
s.append(data_2019)
for df in s:
    for column in df.columns:
        if column not in skupni_atributi:
            df.drop(column, inplace=True, axis=1)

# %%
print(len(data_2000.columns))
print(len(data_2001.columns))
print(len(data_2002.columns))
print(len(data_2003.columns))
print(len(data_2004.columns))
print(len(data_2005.columns))
print(len(data_2006.columns))
print(len(data_2007.columns))
print(len(data_2008.columns))
print(len(data_2009.columns))
print(len(data_2010.columns))
print(len(data_2011.columns))
print(len(data_2012.columns))
print(len(data_2013.columns))
print(len(data_2014.columns))
print(len(data_2015.columns))
print(len(data_2016.columns))
print(len(data_2017.columns))
print(len(data_2018.columns))
print(len(data_2019.columns))
# Out:
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13

# %%
result = pd.concat(s)
result['Avtobusi'] = result['Avtobusi'].fillna(0)
result['Motorji'] = result['Motorji'].fillna(0)
result.sort_values(by='Osebna vozila', ascending=False)
# Out:
#     Kat. ceste Stev. ceste  Stev. odseka                    Prometni odsek  \
# 109         AC          A2            14              LJ (KOSEZE  -  BRDO)
# 109         AC          A2            14              LJ (KOSEZE  -  BRDO)
# 43          AC          A1            48          LJ (ZADOBROVA - ZALOSKA)
# 43          AC          A1            48          LJ (ZADOBROVA - ZALOSKA)
# 46          AC          A1            48  R LJ ZADOBROVA - IND. CONA MOSTE
# ..         ...         ...           ...                               ...
# 100         HC          H4          1467           KAMIONSKA CESTA VRTOJBA
# 77          HC          H4          1467           KAMIONSKA CESTA VRTOJBA
# 783         R3         656          3650                 DRAGARJI-OSILNICA
# 73          AC          A3           372            KAMIONSKA C. FERNETICI
# 926         R3         671          3921        SUTNA - PLANINA V PODBOCJU
#
# ...

# %%
groupedResult = result.groupby(['Prometni odsek']).agg('sum')
groupedResult.drop("Stev. odseka", inplace=True, axis=1)
groupedResult.drop("Stac. zacetka", inplace=True, axis=1)
groupedResult.sort_values(by='Tov. s prik.', ascending=False)
# Out:
#                             Vsa vozila (PLDP)  Motorji  Osebna vozila  \
# Prometni odsek
# BREZOVICA-VRHNIKA                      461711     1981         382105
# SLIVNICA                               680022     1192         516471
# UNEC-POSTOJNA                          256483      760         198658
# VRHNIKA-LOGATEC                        369661     1869         304808
# POSTOJNA-RAZDRTO                       264537     1567         205779
# ...                                       ...      ...            ...
# SUTNA - PLANINA V PODBOCJU                160        2             53
# D.TREBUSA - SP. IDRIJA                    280        6            252
# BOROVEC- DRAGARJI                          50        1             44
# PLAVE-GONJACE                            5176       65           4629
# MP MARTINJE - MARTINJE                   1208       66           1054
#
#                             Avtobusi  Tez. tov. nad 7t  Tov. s prik.
# Prometni odsek
# ...

# %%
list = ["Prometni odsek"]
list.append("Vsa vozila (PLDP)")
list.append("Motorji")
list.append("Osebna vozila")
list.append("Avtobusi")
list.append("Tez. tov. nad 7t")
list.append("Tov. s prik.")

data = []
for ime_odseka, row in groupedResult.iterrows():
    rating_list = []
    rating_list.append(ime_odseka)
    for i in range(6):
        rating_list.append(row[i])
    data.append(rating_list)

df = pd.DataFrame(data, columns=list)
df
# Out:
#                  Prometni odsek  Vsa vozila (PLDP)  Motorji  Osebna vozila  \
# 0                GABRK - DIVACA              46670      238          40466
# 1                 KOTEC-ROGATEC               6300       40           5460
# 2       LJ (MALENCE)-SMARJE-SAP              42710       68          36782
# 3              PODNANOS- VIPAVA               8600       20           5980
# 4      PRIKLJ. LESCE - JESENICE              14030       62          12406
# ...                         ...                ...      ...            ...
# 3076           ZUZEMBERK-PLUSKA               8204      108           6901
# 3077          ZVIRCE - PODTABOR              96056      611          85556
# 3078             ZVIRCE - SMUKA               1596       41           1428
# 3079            ZVIRCE-PODTABOR              69437      384          64830
# 3080               ZVIRCE-SMUKA               2918        9           2579
#
#       Avtobusi  Tez. tov. nad 7t  Tov. s prik.
# ...

# %% [markdown]
# ##Dodajanje stolpca z vsoto vozil:

# %%
import scipy.cluster.hierarchy as sch
import scipy
#L = sch.linkage(dfDropped, method="average", metric="cosine")
dfDropped = df.drop('Prometni odsek', axis=1)
dfDropped = dfDropped.drop(dfDropped.index[456])
a_series = (dfDropped == 0).all(axis=1)
new_df = dfDropped.loc[a_series]
new_df
# Out:
# Empty DataFrame
# Columns: [Vsa vozila (PLDP), Motorji, Osebna vozila, Avtobusi, Tez. tov. nad 7t, Tov. s prik.]
# Index: []

# %%
sumlist = []
for index, row in dfDropped.iterrows():
    sumlist.append(sum(row))
sumlist
dfDropped['SumOfRow'] = sumlist
dfDropped
# Out:
#       Vsa vozila (PLDP)  Motorji  Osebna vozila  Avtobusi  Tez. tov. nad 7t  \
# 0                 46670      238          40466       296               570
# 1                  6300       40           5460        20                70
# 2                 42710       68          36782       242               550
# 3                  8600       20           5980        50               250
# 4                 14030       62          12406        88               118
# ...                 ...      ...            ...       ...               ...
# 3076               8204      108           6901       440                95
# 3077              96056      611          85556       279               755
# 3078               1596       41           1428         7                 9
# 3079              69437      384          64830       197               373
# 3080               2918        9           2579        48                 4
#
#       Tov. s prik.  SumOfRow
# ...
