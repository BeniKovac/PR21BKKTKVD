# %%
import pandas as pd
import csv

# %%
regije_2002 = pd.read_excel("podatki/obcine improved/obcine2002.xls", sheet_name=0)
regije_2003 = pd.read_excel("podatki/obcine improved/obcine2003.xls", sheet_name=0)
regije_2004 = pd.read_excel("podatki/obcine improved/obcine2004.xls", sheet_name=0)
regije_2005 = pd.read_excel("podatki/obcine improved/obcine2005.xls", sheet_name=0)
regije_2006 = pd.read_excel("podatki/obcine improved/obcine2006.xls", sheet_name=0)
regije_2007 = pd.read_excel("podatki/obcine improved/obcine2007.xls", sheet_name=0)
regije_2008 = pd.read_excel("podatki/obcine improved/obcine2008.xls", sheet_name=0)
regije_2009 = pd.read_excel("podatki/obcine improved/obcine2009.xls", sheet_name=0)
regije_2010 = pd.read_excel("podatki/obcine improved/obcine2010.xls", sheet_name=0)
regije_2011 = pd.read_excel("podatki/obcine improved/obcine2011.xls", sheet_name=0)
regije_2012 = pd.read_excel("podatki/obcine improved/obcine2012.xls", sheet_name=0)
regije_2013 = pd.read_excel("podatki/obcine improved/obcine2013.xls", sheet_name=0)
regije_2014 = pd.read_excel("podatki/obcine improved/obcine2014.xls", sheet_name=0)
regije_2015 = pd.read_excel("podatki/obcine improved/obcine2015.xls", sheet_name=0)
regije_2016 = pd.read_excel("podatki/obcine improved/obcine2016.xls", sheet_name=0)
regije_2017 = pd.read_excel("podatki/obcine improved/obcine2017.xls", sheet_name=0)
regije_2018 = pd.read_excel("podatki/obcine improved/obcine2018.xls", sheet_name=0)
regije_2019 = pd.read_excel("podatki/obcine improved/obcine2019.xls", sheet_name=0)
regije = dict()
regije[2002] = regije_2002
regije[2003] = regije_2003
regije[2004] = regije_2004
regije[2005] = regije_2005
regije[2006] = regije_2006
regije[2007] = regije_2007
regije[2008] = regije_2008
regije[2009] = regije_2009
regije[2010] = regije_2010
regije[2011] = regije_2011
regije[2012] = regije_2012
regije[2013] = regije_2013
regije[2014] = regije_2014
regije[2015] = regije_2015
regije[2016] = regije_2016
regije[2017] = regije_2017
regije[2018] = regije_2018
regije[2019] = regije_2019

# %%
path = './podatki/improved/'
data_2002 = pd.read_csv(path+"2002.csv", thousands='.', sep='\s*;\s*', engine='python')
data_2003 = pd.read_csv(path+"2003.csv", thousands='.', sep='\s*;\s*', engine='python')
data_2004 = pd.read_csv(path+"2004.csv", thousands='.', sep='\s*;\s*', engine='python')
data_2005 = pd.read_csv(path+"2005.csv", thousands='.', sep='\s*;\s*', engine='python')
data_2006 = pd.read_csv(path+"2006.csv", thousands='.', sep='\s*;\s*', engine='python')
data_2007 = pd.read_csv(path+"2007.csv", thousands='.', sep='\s*;\s*', engine='python')
data_2008 = pd.read_csv(path+"2008.csv", thousands='.', sep='\s*;\s*', engine='python')
data_2009 = pd.read_csv(path+"2009.csv", thousands='.', sep='\s*;\s*', engine='python')
data_2010 = pd.read_csv(path+"2010.csv", thousands='.', sep='\s*;\s*', engine='python')
data_2011 = pd.read_csv(path+"2011.csv", thousands='.', sep='\s*;\s*', engine='python')
data_2012 = pd.read_csv(path+"2012.csv", thousands='.', sep='\s*;\s*', engine='python')
data_2013 = pd.read_csv(path+"2013.csv", thousands='.', sep='\s*;\s*', engine='python')
data_2014 = pd.read_csv(path+"2014.csv", thousands='.', sep='\s*;\s*', engine='python')
data_2015 = pd.read_csv(path+"2015.csv", thousands='.', sep='\s*;\s*', engine='python')
data_2016 = pd.read_csv(path+"2016.csv", thousands='.', sep='\s*;\s*', engine='python')
data_2017 = pd.read_csv(path+"2017.csv", thousands='.', sep='\s*;\s*', engine='python')
data_2018 = pd.read_csv(path+"2018.csv", thousands='.', sep='\s*;\s*', engine='python')
data_2019 = pd.read_csv(path+"2019.csv", thousands='.', sep='\s*;\s*', engine='python')
dfs = dict()
dfs[2002] = data_2002
dfs[2003] = data_2003
dfs[2004] = data_2004
dfs[2005] = data_2005
dfs[2006] = data_2006
dfs[2007] = data_2007
dfs[2008] = data_2008
dfs[2009] = data_2009
dfs[2010] = data_2010
dfs[2011] = data_2011
dfs[2012] = data_2012
dfs[2013] = data_2013
dfs[2014] = data_2014
dfs[2015] = data_2015
dfs[2016] = data_2016
dfs[2017] = data_2017
dfs[2018] = data_2018
dfs[2019] = data_2019

# %%
headers = set()
merilna_mesta = set()
merilna_mesta_na_zacetku = set()
popolna_merilna_mesta = set()

for i in range(2000, 2020, 1):
    with open(path+str(i)+'.csv', newline='') as csvfile:
        reader = csv.reader(csvfile, delimiter=';', quotechar='"')
        # na zacetku vsakega CSVja je BoM, zato v naslednjem koraku uporabimo [3:]
        vrstica = next(reader)

        # print(', '.join(vrstica)[3:])
        if len(headers) > 0:
            headers = headers.intersection(set(vrstica))
        else:
            headers = set(vrstica)

        trenutna_merilna_mesta = set()
        for vrstica in reader:
            if i == 2000:
                merilna_mesta_na_zacetku.add(vrstica[6])
            merilna_mesta.add(vrstica[6])
            trenutna_merilna_mesta.add(vrstica[6])

        if i == 2000:
            popolna_merilna_mesta = merilna_mesta_na_zacetku
        popolna_merilna_mesta = popolna_merilna_mesta.intersection(trenutna_merilna_mesta)

print(popolna_merilna_mesta)
print(len(popolna_merilna_mesta))
popolna_merilna_mesta = sorted(list(popolna_merilna_mesta))
# Out:
# {'55', '320', '371', '343', '216', '266', '677', '505', '15', '486', '412', '443', '838', '663', '176', '342', '662', '98', '477', '162', '300', '156', '280', '429', '388', '314', '110', '380', '702', '384', '732', '717', '672', '92', '850', '178', '172', '258', '52', '265', '503', '498', '169', '312', '270', '271', '121', '235', '70', '373', '620', '341', '264', '646', '437', '151', '217', '71', '350', '324', '99', '221', '179', '313', '244', '445', '493', '622', '386', '135', '553', '601', '229', '250', '317', '174', '465', '381', '658', '158', '245', '457', '379', '140', '488', '160', '345', '240', '225', '718', '414', '57', '654', '234', '104', '282', '635', '11', '347', '435', '93', '611', '185', '237', '441', '13', '340', '207', '242', '517', '288', '506', '455', '134', '296', '287', '494', '294', '61', '651', '450', '655', '710', '277', '509', '246', '144', '504', '295', '224', '648', '51', '483', '525', '515', '152', '452', '304', '73', '260', '550', '339', '356', '83', '333', '105', '149', '96', '248', '610', '38', '145', '367', '128', '232', '165', '143', '116', '501', '67', '413', '86', '397', '606', '627', '60', '305', '161', '813', '297', '239', '219', '411', '256', '75', '202', '418', '142', '438', '607', '634', '410', '415', '665', '631', '331', '117', '251', '706', '291', '489', '383', '95', '100', '673', '153', '326', '621', '307', '336', '285', '709', '261', '88', '85', '203', '715', '612', '123', '671', '492', '602', '231', '444', '80', '705', '471', '209', '522', '191', '495', '309', '552', '3', '628', '318', '432', '485', '614', '524', '286', '111', '647', '180', '330', '652', '22', '653', '454', '467', '398', '125', '284', '68', '377', '255', '708', '119', '306', '77', '278', '293', '299', '716', '490', '253', '319', '816', '358', '500', '257', '458', '616', '120', '14', '618', '448', '136', '461', '206', '274', '604', '359', '643', '137', '666', '90', '72', '623', '625', '346', '613', '183', '354', '484', '802', '212', '102', '204', '349', '154', '713', '664', '375', '233', '302', '431', '632', '469', '208', '91', '615', '230', '409', '678', '344', '468', '390', '372', '368', '676', '463', '327', '447', '64', '69', '365', '439', '263', '511', '335', '112', '133', '385', '89', '363', '226', '659', '812', '376', '674', '187', '196', '644', '167', '481', '6', '491', '630', '661', '419', '281', '679', '218', '106', '205', '129', '408', '382', '310', '276', '268', '430', '422', '155', '259', '402', '668', '236', '650', '657', '338', '353', '619', '352', '617', '360', '215', '392', '337', '247', '374', '138', '609', '369', '482', '131', '502', '279', '442', '387', '87', '122', '269', '109', '520', '521', '139', '401', '508', '124', '396', '514', '355', '241', '97', '78', '389', '733', '249', '551', '328', '164', '321', '81', '74', '16', '289', '275', '62', '378', '451', '228', '645', '497', '466', '675', '403', '507', '449', '210', '427', '301', '184', '462', '394', '82', '660', '132', '84', '127', '254', '76', '150', '725', '175', '839', '166', '815', '213', '707', '79', '163', '126', '323', '141', '608', '456', '513', '303', '108', '605', '837', '700', '703', '168'}
# 456

# %%
vse_regije = dict()
for regija in regije[2019]['Regija'].unique():
    vse_regije[regije[2019].loc[regije[2019]['Regija'] == regija, "Sif_reg"].iloc[0]] = regija

# %%
regije[2019]
# Out:
#      IVRC CESTA  ODSEK                          OPIS TIPODS  STAC_ZAC  \
# 0      AC    A1     30       MEJA AVSTRIJA - ŠENTILJ      A         0
# 1      AC    A1    630       MEJA AVSTRIJA - ŠENTILJ      V         0
# 2      AC    A1    128               PRIKLJ. ŠENTILJ      P         0
# 3      AC    A1   1650           POČIVALIŠČE ŠENTILJ      D         0
# 4      AC    A1   1651           POČIVALIŠČE ŠENTILJ      D         0
# ...   ...   ...    ...                           ...    ...       ...
# 1933   RT   940   3214  ZAVRHEK - ARTVIŽE - PREGARJE      O      8152
# 1934   RT   940   3214  ZAVRHEK - ARTVIŽE - PREGARJE      O     20398
# 1935   RT   940   3213             PREGARJE - HARIJE      O         0
# 1936   RT   941   1541            GRABONOŠ - RADENCI      O         0
# 1937   RT   941   1541            GRABONOŠ - RADENCI      O       563
#
#       STAC_KON  DOLZINA  SIF_OBC                  IME_OBC  ZAPORED     CP  \
# 0         1137     1137      118                  Šentilj        1  00_VA
# 1         1163     1163      118                  Šentilj        2  00_VA
# 2         1646     1646      118                  Šentilj        3  00_VA
# 3          191      191      118                  Šentilj        4  00_VA
# 4          367      367      118                  Šentilj        5  00_VA
# ...        ...      ...      ...                      ...      ...    ...
# 1933     20398    12246       35         Hrpelje - Kozina     1261  06_KP
# 1934     23588     3190       38         Ilirska Bistrica     1261  06_KP
# 1935      7696     7696       38         Ilirska Bistrica     1262  06_KP
# 1936       563      563      116  Sveti Jurij ob Ščavnici     1263  09_MS
# 1937      7399     6836      100                  Radenci     1263  09_MS
#
#       Sif_reg               Regija
# 0           2            Podravska
# 1           2            Podravska
# 2           2            Podravska
# 3           2            Podravska
# 4           2            Podravska
# ...       ...                  ...
# 1933       12        Obalno-kraška
# 1934       10  Primorskonotranjska
# 1935       10  Primorskonotranjska
# 1936        1             Pomurska
# 1937        1             Pomurska
#
# [1938 rows x 14 columns]

# %%
vse_regije
# Out:
# {2: 'Podravska',
#  4: 'Savinjska',
#  8: 'Osrednjeslovenska',
#  5: 'Zasavska',
#  10: 'Primorskonotranjska',
#  12: 'Obalno-kraška',
#  9: 'Gorenjska',
#  7: 'Jugovzhodna Slovenija',
#  6: 'Posavska',
#  1: 'Pomurska',
#  11: 'Goriška',
#  3: 'Koroška'}

# %%
############################
#   tukaj izberi regijo    #
izbrana_regija = "Savinjska"
############################

# %%
for i in range(2002, 2020):
    dfs[i] = dfs[i][~dfs[i]["Stevno mesto"].isin(popolna_merilna_mesta)]
    #dfs[i].filter()
    #indexes = dfs[i][dfs[i]["Stevno mesto"] not in popolna_merilna_mesta].index
    #dfs[i].drop(indexes, inplace=True)

# %%
dfs[2019]
# Out:
#      Kat. ceste Stev. ceste  Stev. odseka                    Prometni odsek  \
# 4            AC          A1            65               PESNICA - DRAGUCOVA
# 6            AC          A1            71     MB (ZRKOVSKA)  - MB (PTUJSKA)
# 8            AC          A1            66                 ROGOZA - SLIVNICA
# 9            AC          A1            34                          SLIVNICA
# 28           AC          A1            41             SEMPETER - SENTRUPERT
# ...         ...         ...           ...                               ...
# 1174         RT         932          6924                 SL.GRADEC - SPOLE
# 1175         RT         932          6924                   SPOLE - PUNGART
# 1181         RT         935          9042           KOPIVNIK - CESTNIK-AREH
# 1183         RT         937          8710        BRESTRNICA - GAJ-SV. JURIJ
# 1184         RT         938          2503  CERMOSNJICE - KOMARNA V.-GRICICE
#
#       Stac. zacetka  Stac. konca  Stevno mesto Ime stevnega mesta  \
# 4                 0         2570           NaN                NaN
# 6              4452         7770           NaN                NaN
# 8              2590         4857           NaN                NaN
# 9                 0         1757           NaN                NaN
# 28             7511         9652           NaN                NaN
# ...             ...          ...           ...                ...
# 1174              0         4500           NaN                NaN
# 1175           4500        15180           NaN                NaN
# 1181           3600        13900           NaN                NaN
# 1183              0        14162           NaN                NaN
# 1184              0         6317           NaN                NaN
#
#      Tip   stetja  Vsa vozila (PLDP)  Motorji  Osebna vozila  Avtobusi  \
# 4               P              29300       90          22550       240
# 6               P              37800       40          25640       310
# 8               P              42500       40          29810       310
# 9               P              47370       40          34870       315
# 28              P              44000       50          31375       275
# ...           ...                ...      ...            ...       ...
# 1174            P               1260        3           1223         4
# 1175            P                220        0            215         0
# 1181            P                 50        2             46         1
# 1183            P                 50        0             47         0
# 1184            P                 50        3             44         0
#
#       Lah. tov.  < 3,5t  Sr. tov.  3,5-7t  Tez. tov. nad 7t  Tov. s prik.  \
# 4                  3000               200               120           550
# 6                  4350               570               240          1100
# 8                  4700               560               280           900
# 9                  5100               760               415           840
# 28                 5200               700               390           870
# ...                 ...               ...               ...           ...
# 1174                 19                11                 0             0
# 1175                  3                 2                 0             0
# 1181                  1                 0                 0             0
# 1183                  1                 2                 0             0
# 1184                  2                 1                 0             0
#
#       Vlacilci  Dnevni NOO   Tip
# 4         2550        2758  PLDP
# 6         5550        5803  PLDP
# 8         5900        5935  PLDP
# 9         5030        5303  PLDP
# 28        5140        5360  PLDP
# ...        ...         ...   ...
# 1174         0           4  PLDP
# 1175         0           0  PLDP
# 1181         0           0  PLDP
# 1183         0           0  PLDP
# 1184         0           0  PLDP
#
# [276 rows x 20 columns]
