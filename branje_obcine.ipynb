# %%
import pandas as pd

# %%
data_2002 = pd.read_excel("podatki/obcine improved/obcine2002.xls", sheet_name=0)
data_2003 = pd.read_excel("podatki/obcine improved/obcine2003.xls", sheet_name=0)
data_2004 = pd.read_excel("podatki/obcine improved/obcine2004.xls", sheet_name=0)
data_2005 = pd.read_excel("podatki/obcine improved/obcine2005.xls", sheet_name=0)
data_2006 = pd.read_excel("podatki/obcine improved/obcine2006.xls", sheet_name=0)
data_2007 = pd.read_excel("podatki/obcine improved/obcine2007.xls", sheet_name=0)
data_2008 = pd.read_excel("podatki/obcine improved/obcine2008.xls", sheet_name=0)
data_2009 = pd.read_excel("podatki/obcine improved/obcine2009.xls", sheet_name=0)
data_2010 = pd.read_excel("podatki/obcine improved/obcine2010.xls", sheet_name=0)
data_2011 = pd.read_excel("podatki/obcine improved/obcine2011.xls", sheet_name=0)
data_2012 = pd.read_excel("podatki/obcine improved/obcine2012.xls", sheet_name=0)
data_2013 = pd.read_excel("podatki/obcine improved/obcine2013.xls", sheet_name=0)
data_2014 = pd.read_excel("podatki/obcine improved/obcine2014.xls", sheet_name=0)
data_2015 = pd.read_excel("podatki/obcine improved/obcine2015.xls", sheet_name=0)
data_2016 = pd.read_excel("podatki/obcine improved/obcine2016.xls", sheet_name=0)
data_2017 = pd.read_excel("podatki/obcine improved/obcine2017.xls", sheet_name=0)
data_2018 = pd.read_excel("podatki/obcine improved/obcine2018.xls", sheet_name=0)
data_2019 = pd.read_excel("podatki/obcine improved/obcine2019.xls", sheet_name=0)

# %%
data_2009
# Out:
#      IVRC CESTA ODSEK                          OPIS TIPODS  STAC_Z  STAC_K  \
# 0      AC    A1  0030       MEJA AVSTRIJA - ŠENTILJ      A       0    1137
# 1      AC    A1  0630       MEJA AVSTRIJA - ŠENTILJ      V       0    1163
# 2      AC    A1  0128               PRIKLJ. ŠENTILJ      P       0    1580
# 3      AC    A1  1650           POČIVALIŠČE ŠENTILJ      D       0     330
# 4      AC    A1  1651           POČIVALIŠČE ŠENTILJ      D       0     367
# ...   ...   ...   ...                           ...    ...     ...     ...
# 1890   RT   940  3214  ZAVRHEK - ARTVIŽE - PREGARJE      O    8200   20490
# 1891   RT   940  3214  ZAVRHEK - ARTVIŽE - PREGARJE      O   20490   23588
# 1892   RT   940  3213             PREGARJE - HARIJE      O       0    7696
# 1893   RT   941  1541            GRABONOŠ - RADENCI      O       0     560
# 1894   RT   941  1541            GRABONOŠ - RADENCI      O     560    7399
#
#       DOLZINA  SIF_OBC           IME_OBC  ZAPORED     CP  Sif_reg  \
# ...

# %%
data_2019
# Out:
#      IVRC CESTA  ODSEK                          OPIS TIPODS  STAC_ZAC  \
# 0      AC    A1     30       MEJA AVSTRIJA - ŠENTILJ      A         0
# 1      AC    A1    630       MEJA AVSTRIJA - ŠENTILJ      V         0
# 2      AC    A1    128               PRIKLJ. ŠENTILJ      P         0
# 3      AC    A1   1650           POČIVALIŠČE ŠENTILJ      D         0
# 4      AC    A1   1651           POČIVALIŠČE ŠENTILJ      D         0
# ...   ...   ...    ...                           ...    ...       ...
# 1941   RT   940   3214  ZAVRHEK - ARTVIŽE - PREGARJE      O      8152
# 1942   RT   940   3214  ZAVRHEK - ARTVIŽE - PREGARJE      O     20398
# 1943   RT   940   3213             PREGARJE - HARIJE      O         0
# 1944   RT   941   1541            GRABONOŠ - RADENCI      O         0
# 1945   RT   941   1541            GRABONOŠ - RADENCI      O       563
#
#       STAC_KON  DOLZINA  SIF_OBC                  IME_OBC  ZAPORED     CP  \
# ...
