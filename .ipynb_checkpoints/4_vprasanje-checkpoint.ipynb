# %% [markdown]
# Import stavki:

# %%
import csv
import numpy as np
path = './podatki/improved/'
import pandas as pd

# %matplotlib inline
import matplotlib
# %config InlineBackend.figure_format = 'jpg'
matplotlib.figure.Figure.__repr__ = lambda self: (
    f"<{self.__class__.__name__} size {self.bbox.size[0]:g}"
    f"x{self.bbox.size[1]:g} with {len(self.axes)} Axes>")
import matplotlib.pyplot as plt

def get_location(dataframe, key):
    return dataframe.columns.get_loc(key)

main = pd.DataFrame(columns= ["mesto"]+[a for a in range(2000,2020)])

# %%
headers = set()
merilna_mesta = set()
merilna_mesta_na_zacetku = set()
popolna_merilna_mesta = set()

for i in range(2000, 2020, 1):
    with open(path+str(i)+'.csv', newline='') as csvfile:
        reader = csv.reader(csvfile, delimiter=';', quotechar='"')
        # na zacetku vsakega CSVja je BoM, zato v naslednjem koraku uporabimo [3:]
        vrstica = next(reader)

        # print(', '.join(vrstica)[3:])
        if len(headers) > 0:
            headers = headers.intersection(set(vrstica))
        else:
            headers = set(vrstica)

        trenutna_merilna_mesta = set()
        for vrstica in reader:
            if i == 2000:
                merilna_mesta_na_zacetku.add(vrstica[6])
            merilna_mesta.add(vrstica[6])
            trenutna_merilna_mesta.add(vrstica[6])

        if i == 2000:
            popolna_merilna_mesta = merilna_mesta_na_zacetku
        popolna_merilna_mesta = popolna_merilna_mesta.intersection(trenutna_merilna_mesta)

print(popolna_merilna_mesta)
print(len(popolna_merilna_mesta))
popolna_merilna_mesta = sorted(list(popolna_merilna_mesta))
# Out:
# {'169', '208', '178', '700', '16', '488', '450', '385', '492', '119', '161', '129', '484', '218', '326', '504', '215', '126', '160', '651', '503', '632', '621', '444', '125', '369', '331', '281', '412', '247', '251', '304', '64', '365', '371', '270', '465', '501', '447', '430', '268', '120', '408', '309', '483', '715', '494', '413', '495', '207', '158', '850', '179', '255', '375', '196', '96', '92', '419', '666', '289', '82', '210', '466', '481', '658', '163', '341', '217', '505', '102', '249', '514', '623', '60', '259', '674', '709', '269', '202', '513', '652', '342', '606', '72', '307', '303', '135', '145', '284', '612', '411', '232', '668', '358', '221', '601', '52', '622', '604', '384', '3', '61', '705', '345', '673', '432', '213', '455', '653', '85', '71', '551', '609', '74', '286', '324', '318', '634', '355', '257', '167', '330', '650', '344', '339', '276', '521', '137', '328', '449', '410', '244', '233', '219', '209', '266', '383', '732', '237', '703', '619', '477', '294', '78', '644', '116', '314', '708', '117', '620', '67', '458', '256', '431', '617', '347', '295', '191', '15', '109', '462', '517', '95', '205', '552', '802', '442', '275', '733', '235', '317', '635', '614', '183', '605', '142', '675', '490', '81', '438', '121', '515', '100', '346', '150', '664', '630', '279', '124', '104', '155', '394', '140', '340', '628', '397', '511', '452', '676', '467', '717', '168', '97', '225', '429', '152', '133', '250', '86', '427', '241', '338', '136', '360', '254', '713', '162', '671', '265', '134', '226', '618', '815', '707', '657', '441', '234', '22', '89', '352', '401', '203', '87', '335', '240', '288', '174', '813', '816', '509', '837', '647', '139', '282', '508', '388', '415', '14', '376', '631', '493', '321', '263', '451', '277', '73', '367', '264', '57', '111', '280', '616', '154', '706', '185', '379', '435', '187', '112', '377', '93', '679', '212', '550', '306', '55', '90', '69', '68', '228', '437', '239', '373', '506', '648', '625', '716', '285', '337', '245', '151', '507', '80', '231', '468', '608', '258', '380', '248', '661', '75', '602', '382', '422', '206', '381', '485', '611', '356', '386', '299', '98', '11', '274', '482', '105', '246', '354', '368', '350', '456', '164', '812', '91', '665', '500', '349', '396', '660', '62', '838', '242', '414', '305', '702', '374', '184', '457', '76', '655', '454', '461', '13', '392', '387', '70', '230', '336', '278', '291', '106', '627', '128', '471', '38', '672', '502', '302', '725', '99', '353', '165', '77', '224', '138', '463', '153', '127', '343', '261', '553', '175', '143', '497', '646', '88', '445', '180', '313', '402', '84', '418', '293', '710', '310', '525', '110', '333', '83', '659', '663', '141', '610', '156', '51', '287', '409', '216', '403', '359', '486', '123', '323', '144', '172', '372', '662', '301', '204', '271', '320', '524', '327', '469', '678', '491', '108', '122', '312', '300', '176', '132', '149', '229', '677', '6', '615', '607', '520', '613', '390', '839', '79', '131', '522', '253', '443', '389', '439', '448', '378', '319', '166', '297', '398', '236', '260', '296', '489', '363', '498', '654', '643', '718', '645'}
# 456

# %%
data_2000 = pd.read_csv(path+"2000.csv", thousands='.', sep='\s*;\s*', engine='python')
data_2001 = pd.read_csv(path+"2001.csv", thousands='.', sep='\s*;\s*', engine='python')
data_2002 = pd.read_csv(path+"2002.csv", thousands='.', sep='\s*;\s*', engine='python')
data_2003 = pd.read_csv(path+"2003.csv", thousands='.', sep='\s*;\s*', engine='python')
data_2004 = pd.read_csv(path+"2004.csv", thousands='.', sep='\s*;\s*', engine='python')
data_2005 = pd.read_csv(path+"2005.csv", thousands='.', sep='\s*;\s*', engine='python')
data_2006 = pd.read_csv(path+"2006.csv", thousands='.', sep='\s*;\s*', engine='python')
data_2007 = pd.read_csv(path+"2007.csv", thousands='.', sep='\s*;\s*', engine='python')
data_2008 = pd.read_csv(path+"2008.csv", thousands='.', sep='\s*;\s*', engine='python')
data_2009 = pd.read_csv(path+"2009.csv", thousands='.', sep='\s*;\s*', engine='python')
data_2010 = pd.read_csv(path+"2010.csv", thousands='.', sep='\s*;\s*', engine='python')
data_2011 = pd.read_csv(path+"2011.csv", thousands='.', sep='\s*;\s*', engine='python')
data_2012 = pd.read_csv(path+"2012.csv", thousands='.', sep='\s*;\s*', engine='python')
data_2013 = pd.read_csv(path+"2013.csv", thousands='.', sep='\s*;\s*', engine='python')
data_2014 = pd.read_csv(path+"2014.csv", thousands='.', sep='\s*;\s*', engine='python')
data_2015 = pd.read_csv(path+"2015.csv", thousands='.', sep='\s*;\s*', engine='python')
data_2016 = pd.read_csv(path+"2016.csv", thousands='.', sep='\s*;\s*', engine='python')
data_2017 = pd.read_csv(path+"2017.csv", thousands='.', sep='\s*;\s*', engine='python')
data_2018 = pd.read_csv(path+"2018.csv", thousands='.', sep='\s*;\s*', engine='python')
data_2019 = pd.read_csv(path+"2019.csv", thousands='.', sep='\s*;\s*', engine='python')
dfs = dict()
dfs[2000] = data_2000
dfs[2001] = data_2001
dfs[2002] = data_2002
dfs[2003] = data_2003
dfs[2004] = data_2004
dfs[2005] = data_2005
dfs[2006] = data_2006
dfs[2007] = data_2007
dfs[2008] = data_2008
dfs[2009] = data_2009
dfs[2010] = data_2010
dfs[2011] = data_2011
dfs[2012] = data_2012
dfs[2013] = data_2013
dfs[2014] = data_2014
dfs[2015] = data_2015
dfs[2016] = data_2016
dfs[2017] = data_2017
dfs[2018] = data_2018
dfs[2019] = data_2019
# Out:
# <ipython-input-4-a54615753bcf>:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   data_2000 = pd.read_csv(path+"2000.csv", thousands='.', sep='\s*;\s*')
# <ipython-input-4-a54615753bcf>:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   data_2001 = pd.read_csv(path+"2001.csv", thousands='.', sep='\s*;\s*')
# <ipython-input-4-a54615753bcf>:3: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   data_2002 = pd.read_csv(path+"2002.csv", thousands='.', sep='\s*;\s*')
# <ipython-input-4-a54615753bcf>:4: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   data_2003 = pd.read_csv(path+"2003.csv", thousands='.', sep='\s*;\s*')
# <ipython-input-4-a54615753bcf>:5: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   data_2004 = pd.read_csv(path+"2004.csv", thousands='.', sep='\s*;\s*')
# <ipython-input-4-a54615753bcf>:6: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   data_2005 = pd.read_csv(path+"2005.csv", thousands='.', sep='\s*;\s*')
# <ipython-input-4-a54615753bcf>:7: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   data_2006 = pd.read_csv(path+"2006.csv", thousands='.', sep='\s*;\s*')
# <ipython-input-4-a54615753bcf>:8: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   data_2007 = pd.read_csv(path+"2007.csv", thousands='.', sep='\s*;\s*')
# <ipython-input-4-a54615753bcf>:9: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   data_2008 = pd.read_csv(path+"2008.csv", thousands='.', sep='\s*;\s*')
# <ipython-input-4-a54615753bcf>:10: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   data_2009 = pd.read_csv(path+"2009.csv", thousands='.', sep='\s*;\s*')
# <ipython-input-4-a54615753bcf>:11: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   data_2010 = pd.read_csv(path+"2010.csv", thousands='.', sep='\s*;\s*')
# <ipython-input-4-a54615753bcf>:12: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   data_2011 = pd.read_csv(path+"2011.csv", thousands='.', sep='\s*;\s*')
# <ipython-input-4-a54615753bcf>:13: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   data_2012 = pd.read_csv(path+"2012.csv", thousands='.', sep='\s*;\s*')
# <ipython-input-4-a54615753bcf>:14: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   data_2013 = pd.read_csv(path+"2013.csv", thousands='.', sep='\s*;\s*')
# <ipython-input-4-a54615753bcf>:15: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   data_2014 = pd.read_csv(path+"2014.csv", thousands='.', sep='\s*;\s*')
# <ipython-input-4-a54615753bcf>:16: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   data_2015 = pd.read_csv(path+"2015.csv", thousands='.', sep='\s*;\s*')
# <ipython-input-4-a54615753bcf>:17: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   data_2016 = pd.read_csv(path+"2016.csv", thousands='.', sep='\s*;\s*')
# <ipython-input-4-a54615753bcf>:18: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   data_2017 = pd.read_csv(path+"2017.csv", thousands='.', sep='\s*;\s*')
# <ipython-input-4-a54615753bcf>:19: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   data_2018 = pd.read_csv(path+"2018.csv", thousands='.', sep='\s*;\s*')
# <ipython-input-4-a54615753bcf>:20: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   data_2019 = pd.read_csv(path+"2019.csv", thousands='.', sep='\s*;\s*')

# %%
print(data_2000.columns.get_loc("Vsa vozila (PLDP)"))
print(get_location(data_2001, "Vsa vozila (PLDP)"))
print(data_2002.columns.get_loc("Vsa vozila (PLDP)"))
print(data_2003.columns.get_loc("Vsa vozila (PLDP)"))
print(data_2004.columns.get_loc("Vsa vozila (PLDP)"))
print(data_2005.columns.get_loc("Vsa vozila (PLDP)"))
print(data_2006.columns.get_loc("Vsa vozila (PLDP)"))
print(data_2007.columns.get_loc("Vsa vozila (PLDP)"))
print(data_2008.columns.get_loc("Vsa vozila (PLDP)"))
print(data_2009.columns.get_loc("Vsa vozila (PLDP)"))
print(data_2010.columns.get_loc("Vsa vozila (PLDP)"))
print(data_2011.columns.get_loc("Vsa vozila (PLDP)"))
print(data_2012.columns.get_loc("Vsa vozila (PLDP)"))
print(data_2013.columns.get_loc("Vsa vozila (PLDP)"))
print(data_2014.columns.get_loc("Vsa vozila (PLDP)"))
print(data_2015.columns.get_loc("Vsa vozila (PLDP)"))
print(data_2016.columns.get_loc("Vsa vozila (PLDP)"))
print(data_2017.columns.get_loc("Vsa vozila (PLDP)"))
print(data_2018.columns.get_loc("Vsa vozila (PLDP)"))
print(data_2019.columns.get_loc("Vsa vozila (PLDP)"))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-8c0d9e1f3acf> in <module>
# ----> 1 print(data_2000.columns.get_loc("Vsa vozila (PLDP)"))
#       2 print(get_location(data_2001, "Vsa vozila (PLDP)"))
#       3 print(data_2002.columns.get_loc("Vsa vozila (PLDP)"))
#       4 print(data_2003.columns.get_loc("Vsa vozila (PLDP)"))
#       5 print(data_2004.columns.get_loc("Vsa vozila (PLDP)"))
#
# NameError: name 'data_2000' is not defined

# %%
data_2000.set_index('Stevno mesto', inplace=True)
data_2001.set_index('Stevno mesto', inplace=True)
data_2002.set_index('Stevno mesto', inplace=True)
data_2003.set_index('Stevno mesto', inplace=True)
data_2004.set_index('Stevno mesto', inplace=True)
data_2005.set_index('Stevno mesto', inplace=True)
data_2006.set_index('Stevno mesto', inplace=True)
data_2007.set_index('Stevno mesto', inplace=True)
data_2008.set_index('Stevno mesto', inplace=True)
data_2009.set_index('Stevno mesto', inplace=True)
data_2010.set_index('Stevno mesto', inplace=True)
data_2011.set_index('Stevno mesto', inplace=True)
data_2012.set_index('Stevno mesto', inplace=True)
data_2013.set_index('Stevno mesto', inplace=True)
data_2014.set_index('Stevno mesto', inplace=True)
data_2015.set_index('Stevno mesto', inplace=True)
data_2016.set_index('Stevno mesto', inplace=True)
data_2017.set_index('Stevno mesto', inplace=True)
data_2018.set_index('Stevno mesto', inplace=True)
data_2019.set_index('Stevno mesto', inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-3347af8f4b1d> in <module>
# ----> 1 data_2000.set_index('Stevno mesto', inplace=True)
#       2 data_2001.set_index('Stevno mesto', inplace=True)
#       3 data_2002.set_index('Stevno mesto', inplace=True)
#       4 data_2003.set_index('Stevno mesto', inplace=True)
#       5 data_2004.set_index('Stevno mesto', inplace=True)
#
# NameError: name 'data_2000' is not defined

# %%
data_2010
# Out:
#              Kat. ceste Stev. ceste  Stev. odseka  \
# Stevno mesto
# 674                  AC          A1            30
# 869                  AC          A1            30
# 868                  AC          A1           128
# 837                  AC          A1            31
#                      AC          A1            65
# ...                 ...         ...           ...
# 207                  RT         940          1018
# 589                  RT         940          3214
# 593                  RT         940          3214
#                      RT         940          3213
# 343                  RT         941          1541
#
#                                 Prometni odsek  Stac. zacetka  Stac. konca  \
# Stevno mesto
# 674           MP SENTILJ - POCIVALISCE SENTILJ              0          460
# 869              POCIVALISCE SENTILJ - SENTILJ            460         1137
# 868                        PRIKLJ.SENTILJ - MP              0         1444
# 837                        SENTILJ  -  PESNICA              0         9761
#                            PESNICA - DRAGUCOVA              0         2570
# ...                                        ...            ...          ...
# 207                            MATAVUN-ZAVRHEK              0         3707
# 589                          ZAVRHEK - ARTVIZE              0        14830
# 593                         ARTVIZE - PREGARJE          14830        23588
#                              PREGARJE - HARIJE              0         7696
# 343                           VIDEM - GRABONOS              0         7399
#
#               Ime stevnega mesta Tip stetja  Vsa vozila (PLDP)  Motorji  \
# Stevno mesto
# 674                MT Sentilj AC       QLD6              13222       29
# 869                   Sentilj AC      QLTC8              13152       28
# 868           Prik. Sentilj - MP       QLD6                411        1
# 837                   CP Pesnica       QLD3              17776       50
#                              NaN          P              19200       45
# ...                          ...        ...                ...      ...
# 207                        Vreme    R  04x1                750        5
# 589                      Zavrhek    R  08x1                500        1
# 593                   Pregarje-4    R  08x1                240        1
#                              NaN          P                510        9
# 343                    Okoslavci    R  09x4               1130       14
#
#               Osebna vozila  Avtobusi  Lah. tov. < 3,5t  Sr. tov.  3,5-7t  \
# Stevno mesto
# 674                   10090        96              1144               215
# 869                   10055        96              1135               213
# 868                     344         1                25                 4
# 837                   14036       210              1300               215
#                       15185       200              1420               280
# ...                     ...       ...               ...               ...
# 207                     675         5                40                20
# 589                     468         4                15                 7
# 593                     218         1                16                 2
#                         466         1                27                 2
# 343                     992         9                66                32
#
#               Tez. tov. nad 7t  Tov. s prik.  Vlacilci       NOO    TIP
# Stevno mesto
# 674                        138           540       970  14121101  PLDP
# 869                        138           534       953  13735899   PLDP
# 868                          4             7        25    461845   PLDP
# 837                        140           545      1280  17125083   PLDP
#                            290           520      1260  17413736   PLDP
# ...                        ...           ...       ...       ...    ...
# 207                          2             2         1     89582   PLDP
# 589                          2             2         1     59472   PLDP
# 593                          0             1         1     20654   PLDP
#                              3             1         1     35584   PLDP
# 343                         12             2         3    192601   PLDP
#
# [1153 rows x 19 columns]

# %%
data_2000.size
# Out:
# 14858

# %%
#data_2000 = data_2000[data_2000['Vsa vozila (PLDP)'] in popolna_merilna_mesta]
#data_2000 = data_2000[data_2000['Stevno mesto'] in popolna_merilna_mesta]
#df = df[df['line race'] != 0]
#tempIdx = data_2000.index[data_2000['Stevno mesto']]
#data_2000.drop(tempIdx, inplace=True, axis= 0)

# %%
for mesto in popolna_merilna_mesta:
    main = main.append({'mesto': mesto}, ignore_index=True)

main.set_index("mesto", inplace=True)

# %%
main
# Out:
#       2000 2001 2002 2003 2004 2005 2006 2007 2008 2009 2010 2011 2012 2013  \
# mesto
# 100    NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 102    NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 104    NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 105    NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 106    NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# ...    ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 95     NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 96     NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 97     NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 98     NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 99     NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#       2014 2015 2016 2017 2018 2019
# mesto
# 100    NaN  NaN  NaN  NaN  NaN  NaN
# 102    NaN  NaN  NaN  NaN  NaN  NaN
# 104    NaN  NaN  NaN  NaN  NaN  NaN
# 105    NaN  NaN  NaN  NaN  NaN  NaN
# 106    NaN  NaN  NaN  NaN  NaN  NaN
# ...    ...  ...  ...  ...  ...  ...
# 95     NaN  NaN  NaN  NaN  NaN  NaN
# 96     NaN  NaN  NaN  NaN  NaN  NaN
# 97     NaN  NaN  NaN  NaN  NaN  NaN
# 98     NaN  NaN  NaN  NaN  NaN  NaN
# 99     NaN  NaN  NaN  NaN  NaN  NaN
#
# [456 rows x 20 columns]

# %%
for i in range(2000, 2020):
    trenutni = dfs[i]
    for index, row in main.iterrows():
        if trenutni.index.dtype == 'float64':
            temp = trenutni.loc[int(index)]
        else:
            temp = trenutni.loc[index]
        #print(temp)
        if type(temp['Vsa vozila (PLDP)']) != np.int64:
            #print(temp)
            main.at[index, i] = temp['Vsa vozila (PLDP)'].iloc[0]
        else:
            main.at[index, i] = temp['Vsa vozila (PLDP)']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\python39\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: '100'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-53-ff4f385d7c43> in <module>
#       5             temp = trenutni.loc[int(index)]
#       6         else:
# ----> 7             temp = trenutni.loc[index]
#       8         #print(temp)
#       9         if type(temp['Vsa vozila (PLDP)']) != np.int64:
#
# c:\python39\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     893
#     894             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 895             return self._getitem_axis(maybe_callable, axis=axis)
#     896
#     897     def _is_scalar_access(self, key: Tuple):
#
# c:\python39\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1122         # fall thru to straight lookup
#    1123         self._validate_key(key, axis)
# -> 1124         return self._get_label(key, axis=axis)
#    1125
#    1126     def _get_slice_axis(self, slice_obj: slice, axis: int):
#
# c:\python39\lib\site-packages\pandas\core\indexing.py in _get_label(self, label, axis)
#    1071     def _get_label(self, label, axis: int):
#    1072         # GH#5667 this will fail if the label is not present in the axis.
# -> 1073         return self.obj.xs(label, axis=axis)
#    1074
#    1075     def _handle_lowerdim_multi_index_axis0(self, tup: Tuple):
#
# c:\python39\lib\site-packages\pandas\core\generic.py in xs(self, key, axis, level, drop_level)
#    3737                 raise TypeError(f"Expected label or tuple of labels, got {key}") from e
#    3738         else:
# -> 3739             loc = index.get_loc(key)
#    3740
#    3741             if isinstance(loc, np.ndarray):
#
# c:\python39\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: '100'

# %%
main
# Out:
#         2000   2001   2002   2003   2004   2005   2006   2007   2008   2009  \
# mesto
# 100     3400   3500   3500   3563   3811   3935   4268   4099   4092   4069
# 102     2100   2200   2200   2277   2639   2676   2762   2773   2708   2660
# 104     2200   2200   2200   2936   3000   3000   3000   3200   2943   3000
# 105     2000   2000   2000   1885   1900   1900   1900   1900   1740   1794
# 106    11000  11873  12166  12246  12420  12243  12251  12594  12654  12719
# ...      ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 95      9000   9370   9855  10228  10644   9869   9713   9869  10671  11229
# 96      1900   2000   1800   2000   2000   1928   2019   2167   2007   1965
# 97      4000   4000   4000   4000   3584   3580   3600   3700   3674   4612
# 98       450    450    450    450    535    540    540    540    777    780
# 99      5350   6624   6509   6536   6558   6591   6756   7158   7210   7120
#
#       2010 2011 2012 2013 2014 2015 2016 2017 2018 2019
# mesto
# 100    NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 102    NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 104    NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 105    NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 106    NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# ...    ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 95     NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 96     NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 97     NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 98     NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 99     NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
# [456 rows x 20 columns]

# %%
data_2010.index.dtype == 'float64'
# Out:
# False

# %%
data_2010.loc(100)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\python39\lib\site-packages\pandas\core\generic.py in _get_axis_number(cls, axis)
#     459         try:
# --> 460             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     461         except KeyError:
#
# KeyError: 100
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-57-1220cb30a3a9> in <module>
# ----> 1 data_2010.loc(100)
#
# c:\python39\lib\site-packages\pandas\core\indexing.py in __call__(self, axis)
#     605
#     606         if axis is not None:
# --> 607             axis = self.obj._get_axis_number(axis)
#     608         new_self.axis = axis
#     609         return new_self
#
# c:\python39\lib\site-packages\pandas\core\generic.py in _get_axis_number(cls, axis)
#     460             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     461         except KeyError:
# --> 462             raise ValueError(f"No axis named {axis} for object type {cls.__name__}")
#     463
#     464     @final
#
# ValueError: No axis named 100 for object type DataFrame
