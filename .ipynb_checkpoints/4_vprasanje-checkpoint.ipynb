# %% [markdown]
# Import stavki:

# %%
import csv
import numpy as np
path = './podatki/improved/'
import pandas as pd

# %matplotlib inline
import matplotlib
# %config InlineBackend.figure_format = 'jpg'
matplotlib.figure.Figure.__repr__ = lambda self: (
    f"<{self.__class__.__name__} size {self.bbox.size[0]:g}"
    f"x{self.bbox.size[1]:g} with {len(self.axes)} Axes>")
import matplotlib.pyplot as plt

def get_location(dataframe, key):
    return dataframe.columns.get_loc(key)

main = pd.DataFrame(columns= ["mesto"]+[a for a in range(2000,2020)])

# %%
headers = set()
merilna_mesta = set()
merilna_mesta_na_zacetku = set()
popolna_merilna_mesta = set()

for i in range(2000, 2020, 1):
    with open(path+str(i)+'.csv', newline='') as csvfile:
        reader = csv.reader(csvfile, delimiter=';', quotechar='"')
        # na zacetku vsakega CSVja je BoM, zato v naslednjem koraku uporabimo [3:]
        vrstica = next(reader)

        # print(', '.join(vrstica)[3:])
        if len(headers) > 0:
            headers = headers.intersection(set(vrstica))
        else:
            headers = set(vrstica)

        trenutna_merilna_mesta = set()
        for vrstica in reader:
            if i == 2000:
                merilna_mesta_na_zacetku.add(vrstica[6])
            merilna_mesta.add(vrstica[6])
            trenutna_merilna_mesta.add(vrstica[6])

        if i == 2000:
            popolna_merilna_mesta = merilna_mesta_na_zacetku
        popolna_merilna_mesta = popolna_merilna_mesta.intersection(trenutna_merilna_mesta)

print(popolna_merilna_mesta)
print(len(popolna_merilna_mesta))
popolna_merilna_mesta = sorted(list(popolna_merilna_mesta))
# Out:
# {'654', '77', '303', '491', '725', '369', '716', '55', '320', '397', '429', '321', '310', '614', '662', '271', '242', '650', '64', '141', '206', '105', '295', '3', '501', '297', '615', '383', '709', '280', '213', '658', '95', '604', '305', '673', '291', '175', '377', '278', '169', '87', '230', '96', '675', '127', '161', '241', '552', '100', '168', '381', '410', '718', '461', '215', '14', '467', '511', '401', '187', '486', '632', '456', '68', '657', '318', '247', '451', '239', '437', '419', '62', '139', '651', '839', '677', '207', '376', '385', '509', '390', '85', '374', '74', '80', '51', '605', '79', '287', '84', '257', '212', '82', '284', '184', '471', '610', '500', '131', '372', '123', '402', '515', '83', '492', '409', '286', '439', '110', '389', '219', '627', '120', '312', '57', '102', '702', '150', '228', '216', '396', '524', '481', '285', '522', '176', '204', '151', '337', '73', '172', '304', '356', '359', '264', '706', '22', '143', '326', '412', '302', '81', '520', '289', '387', '152', '494', '122', '109', '259', '336', '443', '111', '229', '815', '347', '485', '281', '517', '301', '276', '666', '340', '160', '371', '245', '652', '378', '179', '375', '363', '342', '90', '217', '715', '550', '116', '16', '135', '671', '121', '647', '503', '484', '210', '513', '330', '52', '155', '158', '616', '266', '466', '263', '6', '288', '703', '76', '646', '38', '708', '136', '612', '733', '454', '344', '178', '231', '165', '837', '253', '313', '415', '350', '324', '93', '352', '196', '153', '601', '622', '11', '224', '625', '339', '493', '469', '104', '648', '274', '508', '450', '611', '497', '236', '218', '119', '488', '237', '132', '455', '226', '154', '462', '69', '668', '293', '183', '97', '299', '452', '617', '140', '254', '838', '258', '463', '138', '133', '802', '672', '156', '209', '710', '98', '225', '382', '608', '495', '609', '368', '331', '341', '713', '663', '328', '255', '294', '233', '232', '235', '106', '457', '124', '99', '482', '248', '551', '309', '700', '88', '427', '265', '379', '623', '607', '386', '645', '606', '490', '234', '619', '553', '365', '203', '430', '145', '621', '86', '447', '813', '414', '164', '431', '180', '442', '514', '327', '323', '112', '384', '373', '75', '630', '631', '117', '108', '149', '129', '502', '643', '268', '679', '354', '261', '246', '664', '644', '505', '498', '388', '174', '732', '489', '458', '422', '317', '244', '449', '345', '661', '678', '660', '333', '507', '635', '185', '674', '306', '249', '360', '15', '816', '163', '314', '408', '812', '394', '338', '665', '221', '13', '483', '128', '602', '398', '137', '260', '92', '343', '655', '525', '504', '349', '71', '367', '307', '441', '126', '506', '521', '444', '296', '270', '432', '208', '403', '438', '618', '355', '91', '191', '717', '78', '477', '335', '250', '353', '202', '445', '61', '634', '676', '705', '620', '277', '162', '282', '850', '125', '413', '167', '411', '256', '240', '300', '269', '134', '144', '72', '380', '392', '659', '628', '346', '653', '279', '70', '275', '142', '465', '60', '418', '448', '707', '89', '468', '166', '205', '67', '435', '613', '251', '358', '319'}
# 456

# %%
data_2000 = pd.read_csv(path+"2000.csv", sep=";", thousands='.')
data_2001 = pd.read_csv(path+"2001.csv", sep=";", thousands='.')
data_2002 = pd.read_csv(path+"2002.csv", sep=";", thousands='.')
data_2003 = pd.read_csv(path+"2003.csv", sep=";", thousands='.')
data_2004 = pd.read_csv(path+"2004.csv", sep=";", thousands='.')
data_2005 = pd.read_csv(path+"2005.csv", sep=";", thousands='.')
data_2006 = pd.read_csv(path+"2006.csv", sep=";", thousands='.')
data_2007 = pd.read_csv(path+"2007.csv", sep=";", thousands='.')
data_2008 = pd.read_csv(path+"2008.csv", sep=";", thousands='.')
data_2009 = pd.read_csv(path+"2009.csv", sep=";", thousands='.')
data_2010 = pd.read_csv(path+"2010.csv", sep=";", thousands='.')
data_2011 = pd.read_csv(path+"2011.csv", sep=";", thousands='.')
data_2012 = pd.read_csv(path+"2012.csv", sep=";", thousands='.')
data_2013 = pd.read_csv(path+"2013.csv", sep=";", thousands='.')
data_2014 = pd.read_csv(path+"2014.csv", sep=";", thousands='.')
data_2015 = pd.read_csv(path+"2015.csv", sep=";", thousands='.')
data_2016 = pd.read_csv(path+"2016.csv", sep=";", thousands='.')
data_2017 = pd.read_csv(path+"2017.csv", sep=";", thousands='.')
data_2018 = pd.read_csv(path+"2018.csv", sep=";", thousands='.')
data_2019 = pd.read_csv(path+"2019.csv", sep=";", thousands='.')
dfs = dict()
dfs[2000] = data_2000
dfs[2001] = data_2001
dfs[2002] = data_2002
dfs[2003] = data_2003
dfs[2004] = data_2004
dfs[2005] = data_2005
dfs[2006] = data_2006
dfs[2007] = data_2007
dfs[2008] = data_2008
dfs[2009] = data_2009
dfs[2010] = data_2010
dfs[2011] = data_2011
dfs[2012] = data_2012
dfs[2013] = data_2013
dfs[2014] = data_2014
dfs[2015] = data_2015
dfs[2016] = data_2016
dfs[2017] = data_2017
dfs[2018] = data_2018
dfs[2019] = data_2019

# %%
print(data_2000.columns.get_loc("Vsa vozila (PLDP)"))
print(get_location(data_2001, "Vsa vozila (PLDP)"))
print(data_2002.columns.get_loc("Vsa vozila (PLDP)"))
print(data_2003.columns.get_loc("Vsa vozila (PLDP)"))
print(data_2004.columns.get_loc("Vsa vozila (PLDP)"))
print(data_2005.columns.get_loc("Vsa vozila (PLDP)"))
print(data_2006.columns.get_loc("Vsa vozila (PLDP)"))
print(data_2007.columns.get_loc("Vsa vozila (PLDP)"))
print(data_2008.columns.get_loc("Vsa vozila (PLDP)"))
print(data_2009.columns.get_loc("Vsa vozila (PLDP)"))
print(data_2010.columns.get_loc("Vsa vozila (PLDP)"))
print(data_2011.columns.get_loc("Vsa vozila (PLDP)"))
print(data_2012.columns.get_loc("Vsa vozila (PLDP)"))
print(data_2013.columns.get_loc("Vsa vozila (PLDP)"))
print(data_2014.columns.get_loc("Vsa vozila (PLDP)"))
print(data_2015.columns.get_loc("Vsa vozila (PLDP)"))
print(data_2016.columns.get_loc("Vsa vozila (PLDP)"))
print(data_2017.columns.get_loc("Vsa vozila (PLDP)"))
print(data_2018.columns.get_loc("Vsa vozila (PLDP)"))
print(data_2019.columns.get_loc("Vsa vozila (PLDP)"))
# Out:
# 10
# 10
# 11
# 11
# 11
# 11
# 11
# 11
# 10
# 10
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9

# %%
data_2000.set_index('Stevno mesto', inplace=True)
data_2001.set_index('Stevno mesto', inplace=True)
data_2002.set_index('Stevno mesto', inplace=True)
data_2003.set_index('Stevno mesto', inplace=True)
data_2004.set_index('Stevno mesto', inplace=True)
data_2005.set_index('Stevno mesto', inplace=True)
data_2006.set_index('Stevno mesto', inplace=True)
data_2007.set_index('Stevno mesto', inplace=True)
data_2008.set_index('Stevno mesto', inplace=True)
data_2009.set_index('Stevno mesto', inplace=True)
data_2010.set_index('Stevno mesto', inplace=True)
data_2011.set_index('Stevno mesto', inplace=True)
data_2012.set_index('Stevno mesto', inplace=True)
data_2013.set_index('Stevno mesto', inplace=True)
data_2014.set_index('Stevno mesto', inplace=True)
data_2015.set_index('Stevno mesto', inplace=True)
data_2016.set_index('Stevno mesto', inplace=True)
data_2017.set_index('Stevno mesto', inplace=True)
data_2018.set_index('Stevno mesto', inplace=True)
data_2019.set_index('Stevno mesto', inplace=True)

# %%
data_2000
# Out:
#              Kat. ceste Stev. ceste  Stev. odseka       Prometni odsek  \
# Stevno mesto
# 674                  AC          A1            30  M.P.SENTILJ-SENTILJ
# 837                  AC          A1            31    SENTILJ - PESNICA
# 802                  AC          A1            34             SLIVNICA
# 802                  AC          A1            35        SLIVNICA-FRAM
# 802                  AC          A1            36     FRAM-SL.BISTRICA
# ...                 ...         ...           ...                  ...
# 454                  RT         933          1193          BREG- LISCA
# 287                  RT         933          1193     LISCA-JURKLOSTER
# 57                   RT         934          6838        SEZANA-LIPICA
# 75                   RT         934          6840         LIPICA-LOKEV
# 495                  RT         935          9042    FRAM-CESTNIK-AREH
#
#               Stac. zacetka  Stac. konca Tip pr. odseka Tip avt. stevca  \
# Stevno mesto
# 674                       0         1230              O            QLD3
# 837                       0         9550              O            QLD3
# 802                       0         1700              P             NaN
# 802                       0         1910              O            QLD6
# 802                       0         9740              P             NaN
# ...                     ...          ...            ...             ...
# 454                       0         4650              O             NaN
# 287                    4650        12370              O             NaN
# 57                        0         3494              O             NaN
# 75                        0         4139              O             NaN
# 495                       0        13900              P             NaN
#
#              Ime stevnega mesta  Vsa vozila (PLDP)  Motorji  Osebna vozila  \
# Stevno mesto
# 674             M.P. SENTILJ AC              8.712       32          8.456
# 837                C.P. PESNICA             10.018       40          9.280
# 802                         NaN             22.578       52         18.396
# 802                    C.P.HOCE             22.578       52         18.396
# 802                         NaN             19.000       44         15.482
# ...                         ...                ...      ...            ...
# 454                      BREG 1            500.000        5        459.000
# 287                  JURKLOSTER            250.000        7        223.000
# 57                      LOKEV 1              1.856       13          1.698
# 75                      LOKEV 2            613.000        0        545.000
# 495                         NaN             50.000        0         45.000
#
#               Avtobusi  Lahka tov. < 3t  Sr. tov.  3-7t  Tez. tov. nad 7t  \
# Stevno mesto
# 674                 56          150.000            18.0               0.0
# 837                 64          240.000            70.0              12.0
# 802                108            1.562           812.0             580.0
# 802                108            1.562           812.0             580.0
# 802                 90            1.314           684.0             488.0
# ...                ...              ...             ...               ...
# 454                  2           22.000            12.0               0.0
# 287                  5           14.000             1.0               0.0
# 57                  17           77.000            47.0               2.0
# 75                   2           38.000            27.0               0.0
# 495                  1            2.000             1.0               1.0
#
#               Tov. s prik.
# Stevno mesto
# 674                  0.000
# 837                312.000
# 802                  1.068
# 802                  1.068
# 802                898.000
# ...                    ...
# 454                  0.000
# 287                  0.000
# 57                   2.000
# 75                   1.000
# 495                  0.000
#
# [874 rows x 17 columns]

# %%
data_2000.size
# Out:
# 15732

# %%
#data_2000 = data_2000[data_2000['Vsa vozila (PLDP)'] in popolna_merilna_mesta]
#data_2000 = data_2000[data_2000['Stevno mesto'] in popolna_merilna_mesta]
#df = df[df['line race'] != 0]
#tempIdx = data_2000.index[data_2000['Stevno mesto']]
#data_2000.drop(tempIdx, inplace=True, axis= 0)

# %%
for mesto in popolna_merilna_mesta:
    main = main.append({'mesto': mesto}, ignore_index=True)

main.set_index("mesto", inplace=True)

# %%
main
# Out:
#       2000 2001 2002 2003 2004 2005 2006 2007 2008 2009 2010 2011 2012 2013  \
# mesto
# 100    NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 102    NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 104    NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 105    NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 106    NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# ...    ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 95     NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 96     NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 97     NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 98     NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 99     NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#       2014 2015 2016 2017 2018 2019
# mesto
# 100    NaN  NaN  NaN  NaN  NaN  NaN
# 102    NaN  NaN  NaN  NaN  NaN  NaN
# 104    NaN  NaN  NaN  NaN  NaN  NaN
# 105    NaN  NaN  NaN  NaN  NaN  NaN
# 106    NaN  NaN  NaN  NaN  NaN  NaN
# ...    ...  ...  ...  ...  ...  ...
# 95     NaN  NaN  NaN  NaN  NaN  NaN
# 96     NaN  NaN  NaN  NaN  NaN  NaN
# 97     NaN  NaN  NaN  NaN  NaN  NaN
# 98     NaN  NaN  NaN  NaN  NaN  NaN
# 99     NaN  NaN  NaN  NaN  NaN  NaN
#
# [456 rows x 20 columns]

# %%
for i in range(2000, 2020):
    trenutni = dfs[i]
    for index, row in main.iterrows():
        temp = trenutni.loc[int(index)]
        #print(temp)
        #if len(temp.index) == 1:
        main.at[index, i] = temp['Vsa vozila (PLDP)']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\python39\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine._maybe_get_bool_indexer()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine._unpack_bool_indexer()
#
# KeyError: 100
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-212d8c06f54d> in <module>
#       2     trenutni = dfs[i]
#       3     for index, row in main.iterrows():
# ----> 4         temp = trenutni.loc[int(index)]
#       5         #print(temp)
#       6         #if len(temp.index) == 1:
#
# c:\python39\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     893
#     894             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 895             return self._getitem_axis(maybe_callable, axis=axis)
#     896
#     897     def _is_scalar_access(self, key: Tuple):
#
# c:\python39\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1122         # fall thru to straight lookup
#    1123         self._validate_key(key, axis)
# -> 1124         return self._get_label(key, axis=axis)
#    1125
#    1126     def _get_slice_axis(self, slice_obj: slice, axis: int):
#
# c:\python39\lib\site-packages\pandas\core\indexing.py in _get_label(self, label, axis)
#    1071     def _get_label(self, label, axis: int):
#    1072         # GH#5667 this will fail if the label is not present in the axis.
# -> 1073         return self.obj.xs(label, axis=axis)
#    1074
#    1075     def _handle_lowerdim_multi_index_axis0(self, tup: Tuple):
#
# c:\python39\lib\site-packages\pandas\core\generic.py in xs(self, key, axis, level, drop_level)
#    3737                 raise TypeError(f"Expected label or tuple of labels, got {key}") from e
#    3738         else:
# -> 3739             loc = index.get_loc(key)
#    3740
#    3741             if isinstance(loc, np.ndarray):
#
# c:\python39\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 100

# %%
main
# Out:
#                                                     2000  \
# mesto
# 100                                                  3.4
# 102                                                  2.1
# 104                                                  2.2
# 105    Stevno mesto
# 105    2.0
# 105    2.3
# Name: Vsa v...
# 106                                                 11.0
# ...                                                  ...
# 95     Stevno mesto
# 95    9.0
# 95    9.0
# Name: Vsa voz...
# 96     Stevno mesto
# 96    1.900
# 96    1.927
# Name: Vsa...
# 97                                                   4.0
# 98                                                 450.0
# 99     Stevno mesto
# 99     5.35
# 99    14.60
# Name: Vsa...
#
#                                                     2001  \
# mesto
# 100                                                  3.5
# 102                                                  2.2
# 104                                                  2.2
# 105    Stevno mesto
# 105    2.0
# 105    2.3
# Name: Vsa v...
# 106                                               11.873
# ...                                                  ...
# 95     Stevno mesto
# 95    9.37
# 95    9.40
# Name: Vsa v...
# 96     Stevno mesto
# 96    2.0
# 96    2.0
# Name: Vsa voz...
# 97                                                   4.0
# 98                                                 450.0
# 99     Stevno mesto
# 99     6.624
# 99    15.000
# Name: V...
#
#                                                     2002  \
# mesto
# 100                                                  3.5
# 102                                                  2.2
# 104                                                  2.2
# 105    Stevno mesto
# 105    2.0
# 105    1.0
# Name: Vsa v...
# 106                                               12.166
# ...                                                  ...
# 95     Stevno mesto
# 95    9.855
# 95    9.500
# Name: Vsa...
# 96     Stevno mesto
# 96    1.800
# 96    1.576
# Name: Vsa...
# 97                                                   4.0
# 98                                                 450.0
# 99     Stevno mesto
# 99     6.509
# 99    15.000
# Name: V...
#
#                                                     2003  \
# mesto
# 100                                                3.563
# 102                                                2.277
# 104                                                2.936
# 105    Stevno mesto
# 105    1.885
# 105    1.000
# Name: V...
# 106                                               12.246
# ...                                                  ...
# 95     Stevno mesto
# 95    10.228
# 95    10.200
# Name: V...
# 96     Stevno mesto
# 96    2.000
# 96    1.927
# Name: Vsa...
# 97                                                   4.0
# 98                                                 450.0
# 99     Stevno mesto
# 99     6.536
# 99    15.166
# Name: V...
#
#                                                     2004    2005    2006  \
# mesto
# 100                                                3.811   3.935   4.268
# 102                                                2.639   2.676   2.762
# 104                                                  3.0     3.0     3.0
# 105    Stevno mesto
# 105    1.9
# 105    1.0
# Name: Vsa v...     1.9     1.9
# 106                                                12.42  12.243  12.251
# ...                                                  ...     ...     ...
# 95     Stevno mesto
# 95    10.644
# 95    10.600
# Name: V...   9.869   9.713
# 96     Stevno mesto
# 96    2.000
# 96    1.947
# Name: Vsa...   1.928   2.019
# 97                                                 3.584    3.58     3.6
# 98                                                 535.0   540.0   540.0
# 99     Stevno mesto
# 99     6.558
# 99    15.200
# Name: V...   6.591   6.756
#
#          2007    2008    2009 2010 2011 2012 2013 2014 2015 2016 2017 2018  \
# mesto
# 100     4.099   4.092   4.069  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 102     2.773   2.708    2.66  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 104       3.2   2.943     3.0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 105       1.9    1.74   1.794  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 106    12.594  12.654  12.719  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# ...       ...     ...     ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 95      9.869  10.671  11.229  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 96      2.167   2.007   1.965  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 97        3.7   3.674   4.612  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 98      540.0   777.0   780.0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 99      7.158    7.21    7.12  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#       2019
# mesto
# 100    NaN
# 102    NaN
# 104    NaN
# 105    NaN
# 106    NaN
# ...    ...
# 95     NaN
# 96     NaN
# 97     NaN
# 98     NaN
# 99     NaN
#
# [456 rows x 20 columns]
