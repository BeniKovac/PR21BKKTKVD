# %%
import pandas as pd
data_2000 = pd.read_csv("podatki/improved/2000.csv", sep=";")
data_2000
# Out:
#     Kat. ceste Stev. ceste  Stev. odseka       Prometni odsek  Stac. zacetka  \
# 0           AC          A1            30  M.P.SENTILJ-SENTILJ              0
# 1           AC          A1            31    SENTILJ - PESNICA              0
# 2           AC          A1            34             SLIVNICA              0
# 3           AC          A1            35        SLIVNICA-FRAM              0
# 4           AC          A1            36     FRAM-SL.BISTRICA              0
# ..         ...         ...           ...                  ...            ...
# 869         RT         933          1193          BREG- LISCA              0
# 870         RT         933          1193     LISCA-JURKLOSTER           4650
# 871         RT         934          6838        SEZANA-LIPICA              0
# 872         RT         934          6840         LIPICA-LOKEV              0
# 873         RT         935          9042    FRAM-CESTNIK-AREH              0
#
# ...

# %%
data_2001 = pd.read_csv("podatki/improved/2001.csv", sep=";")
data_2001
# Out:
#     Kat. ceste Stev. ceste  Stev. odseka                  Prometni odsek  \
# 0           AC          A1            30              MP SENTILJ-SENTILJ
# 1           AC          A1            31               SENTILJ - PESNICA
# 2           AC          A1            66       MARIBOR(PTUJSKA)-SLIVNICA
# 3           AC          A1            34                        SLIVNICA
# 4           AC          A1            35                   SLIVNICA-FRAM
# ..         ...         ...           ...                             ...
# 917         RT         934          6840                    LIPICA-LOKEV
# 918         RT         935          9042               FRAM-CESTNIK-AREH
# 919         RT         936          1063                    COL-PREDMEJA
# 920         RT         937          8710        BRESTRNICA-GAJ-SV. JURIJ
# 921         RT         938          2503  CERMOSNJICE-KOMARNA V.-GRICICE
#
#      Stac. zacetka  Stac. Konca  Stevno mesto Tip pr. odseka Tip avt. stevca  \
# ...

# %%
data_2002 = pd.read_csv("podatki/improved/2002.csv", sep=";")
data_2002
# Out:
#     Kat. ceste Stev. ceste  Stev. odseka                  Prometni odsek  \
# 0           AC          A1            30              MP SENTILJ-SENTILJ
# 1           AC          A1            31               SENTILJ - PESNICA
# 2           AC          A1            66       MARIBOR(PTUJSKA)-SLIVNICA
# 3           AC          A1            34                        SLIVNICA
# 4           AC          A1            35                   SLIVNICA-FRAM
# ..         ...         ...           ...                             ...
# 923         RT         934          6840                    LIPICA-LOKEV
# 924         RT         935          9042               FRAM-CESTNIK-AREH
# 925         RT         936          1063                    COL-PREDMEJA
# 926         RT         937          8710        BRESTRNICA-GAJ-SV. JURIJ
# 927         RT         938          2503  CERMOSNJICE-KOMARNA V.-GRICICE
#
#      Stac. zacetka  Stac. konca  Stevno mesto Tip pr. odseka Tip avt. stevca  \
# ...

# %%
data_2003 = pd.read_csv("podatki/improved/2003.csv", sep=";")
data_2003
# Out:
#     Kat. ceste Stev. ceste  Stev. odseka                  Prometni odsek  \
# 0           AC          A1            30              MP SENTILJ-SENTILJ
# 1           AC          A1            31               SENTILJ - PESNICA
# 2           AC          A1            66       MARIBOR(PTUJSKA)-SLIVNICA
# 3           AC          A1            34                        SLIVNICA
# 4           AC          A1            35                   SLIVNICA-FRAM
# ..         ...         ...           ...                             ...
# 938         RT         934          6840                    LIPICA-LOKEV
# 939         RT         935          9042               FRAM-CESTNIK-AREH
# 940         RT         936          1063                    COL-PREDMEJA
# 941         RT         937          8710        BRESTRNICA-GAJ-SV. JURIJ
# 942         RT         938          2503  CERMOSNJICE-KOMARNA V.-GRICICE
#
#      Stac. zacetka  Stac. konca  Stevno mesto Tip pr. odseka Tip avt. stevca  \
# ...

# %%
data_2004 = pd.read_csv("podatki/improved/2004.csv", sep=";")
data_2004
# Out:
#     Kat. ceste Stev. ceste  Stev. odseka                  Prometni odsek  \
# 0           AC          A1            30              MP SENTILJ-SENTILJ
# 1           AC          A1            31               SENTILJ - PESNICA
# 2           AC          A1            66       MARIBOR(PTUJSKA)-SLIVNICA
# 3           AC          A1            34                        SLIVNICA
# 4           AC          A1            35                   SLIVNICA-FRAM
# ..         ...         ...           ...                             ...
# 940         RT         934          6840                    LIPICA-LOKEV
# 941         RT         935          9042               FRAM-CESTNIK-AREH
# 942         RT         936          1063                    COL-PREDMEJA
# 943         RT         937          8710        BRESTRNICA-GAJ-SV. JURIJ
# 944         RT         938          2503  CERMOSNJICE-KOMARNA V.-GRICICE
#
#      Stac. zacetka  Stac. konca  Stevno mesto Tip pr. odseka Tip avt. stevca  \
# ...

# %%
data_2005 = pd.read_csv("podatki/improved/2005.csv", sep=";")
data_2005
# Out:
#      Kat. ceste Stev. ceste  Stev. odseka                  Prometni odsek  \
# 0            AC          A1            30              MP SENTILJ-SENTILJ
# 1            AC          A1            31               SENTILJ - PESNICA
# 2            AC          A1            66              MB(PTUJSKA)-ROGOZA
# 3            AC          A1            66                 ROGOZA-SLIVNICA
# 4            AC          A1            34                        SLIVNICA
# ...         ...         ...           ...                             ...
# 1015         RT         934          6840                    LIPICA-LOKEV
# 1016         RT         935          9042               FRAM-CESTNIK-AREH
# 1017         RT         936          1063                    COL-PREDMEJA
# 1018         RT         937          8710        BRESTRNICA-GAJ-SV. JURIJ
# 1019         RT         938          2503  CERMOSNJICE-KOMARNA V.-GRICICE
#
#       Stac. zacetka  Stac. konca  Stevno mesto Tip pr. odseka Tip avt. stevca  \
# ...

# %%
data_2006 = pd.read_csv("podatki/improved/2006.csv", sep=";")
data_2006
# Out:
#      Kat. ceste Stev. ceste  Stev. odseka                  Prometni odsek  \
# 0            AC          A1            30              MP SENTILJ-SENTILJ
# 1            AC          A1            31               SENTILJ - PESNICA
# 2            AC          A1            66              MB(PTUJSKA)-ROGOZA
# 3            AC          A1            66                 ROGOZA-SLIVNICA
# 4            AC          A1            34                        SLIVNICA
# ...         ...         ...           ...                             ...
# 1041         RT         934          6840                    LIPICA-LOKEV
# 1042         RT         935          9042               FRAM-CESTNIK-AREH
# 1043         RT         936          1063                    COL-PREDMEJA
# 1044         RT         937          8710        BRESTRNICA-GAJ-SV. JURIJ
# 1045         RT         938          2503  CERMOSNJICE-KOMARNA V.-GRICICE
#
#       Stac. zacetka  Stac. konca  Stevno mesto Tip pr. odseka Tip avt. stevca  \
# ...

# %%
data_2007 = pd.read_csv("podatki/improved/2007.csv", sep=";")
data_2007
# Out:
#      Kat. ceste Stev. ceste  Stev. odseka                  Prometni odsek  \
# 0            AC          A1            30  MP SENTILJ-POCIVALISCE SENTILJ
# 1            AC          A1            30     POCIVALISCE SENTILJ-SENTILJ
# 2            AC          A1           128               PRIKLJ.SENTILJ-MP
# 3            AC          A1            31               SENTILJ - PESNICA
# 4            AC          A1            66              MB(PTUJSKA)-ROGOZA
# ...         ...         ...           ...                             ...
# 1075         RT         935          9042               FRAM-CESTNIK-AREH
# 1076         RT         936          1063                    COL-PREDMEJA
# 1077         RT         937          8710        BRESTRNICA-GAJ-SV. JURIJ
# 1078         RT         938          2503  CERMOSNJICE-KOMARNA V.-GRICICE
# 1079         RT         939          3815                        PREDDVOR
#
#       Stac. zacetka  Stac. konca  Stevno mesto Tip pr. odseka Tip avt. stevca  \
# ...

# %%
data_2008 = pd.read_csv("podatki/improved/2008.csv", sep=";")
data_2008
# Out:
#      Kat. ceste Stev. ceste  Stev. odseka                  Prometni odsek  \
# 0            AC          A1            30  MP SENTILJ-POCIVALISCE SENTILJ
# 1            AC          A1            30     POCIVALISCE SENTILJ-SENTILJ
# 2            AC          A1           128               PRIKLJ.SENTILJ-MP
# 3            AC          A1            31                SENTILJ- PESNICA
# 4            AC          A1            65               PESNICA-DRAGUCOVA
# ...         ...         ...           ...                             ...
# 1126         RT         940          1018                   MATAVUN-VREME
# 1127         RT         940          3214                 ZAVRHEK-ARTVIZE
# 1128         RT         940          3214                ARTVIZE-PREGARJE
# 1129         RT         940          3213                 PREGARJE-HARIJE
# 1130         RT         941          1541                   VIDEM-RADENCI
#
#       Stac. zacetka  Stac. konca  Stevno mesto  Ime stevnega mesta Tip stetja  \
# ...

# %%
data_2009 = pd.read_csv("podatki/improved/2009.csv", sep=";")
data_2009
# Out:
#      Kat. ceste Stev. ceste  Stev. odseka                    Prometni odsek  \
# 0            AC          A1            30  MP SENTILJ - POCIVALISCE SENTILJ
# 1            AC          A1            30     POCIVALISCE SENTILJ - SENTILJ
# 2            AC          A1           128               PRIKLJ.SENTILJ - MP
# 3            AC          A1            31               SENTILJ  -  PESNICA
# 4            AC          A1            65               PESNICA - DRAGUCOVA
# ...         ...         ...           ...                               ...
# 1136         RT         940          1018                   MATAVUN - VREME
# 1137         RT         940          3214                ZAVRHEK - ARTVIZE
# 1138         RT         940          3214                ARTVIZE - PREGARJE
# 1139         RT         940          3213                 PREGARJE - HARIJE
# 1140         RT         941          1541                   VIDEM - RADENCI
#
# ...

# %%
data_2010 = pd.read_csv("podatki/improved/2010.csv", sep=";")
data_2010
# Out:
#      Kat. ceste Stev. ceste  Stev. odseka                    Prometni odsek  \
# 0            AC          A1            30  MP SENTILJ - POCIVALISCE SENTILJ
# 1            AC          A1            30     POCIVALISCE SENTILJ - SENTILJ
# 2            AC          A1           128               PRIKLJ.SENTILJ - MP
# 3            AC          A1            31               SENTILJ  -  PESNICA
# 4            AC          A1            65               PESNICA - DRAGUCOVA
# ...         ...         ...           ...                               ...
# 1148         RT         940          1018                   MATAVUN-ZAVRHEK
# 1149         RT         940          3214                 ZAVRHEK - ARTVIZE
# 1150         RT         940          3214                ARTVIZE - PREGARJE
# 1151         RT         940          3213                 PREGARJE - HARIJE
# 1152         RT         941          1541                  VIDEM - GRABONOS
#
# ...

# %%
data_2011 = pd.read_csv("podatki/improved/2011.csv", sep=";")
data_2011
# Out:
#      Kat. ceste Stev. ceste  Stev. odseka                    Prometni odsek  \
# 0            AC          A1            30  MP SENTILJ - POCIVALISCE SENTILJ
# 1            AC          A1            30     POCIVALISCE SENTILJ - SENTILJ
# 2            AC          A1           128               PRIKLJ.SENTILJ - MP
# 3            AC          A1            31               SENTILJ  -  PESNICA
# 4            AC          A1            65               PESNICA - DRAGUCOVA
# ...         ...         ...           ...                               ...
# 1152         RT         940          1018                   MATAVUN-ZAVRHEK
# 1153         RT         940          3214                 ZAVRHEK - ARTVIZE
# 1154         RT         940          3214                ARTVIZE - PREGARJE
# 1155         RT         940          3213                 PREGARJE - HARIJE
# 1156         RT         941          1541                  GRABONOS-RADENCI
#
# ...

# %%
data_2012 = pd.read_csv("podatki/improved/2012.csv", sep=";")
data_2012
# Out:
#      Kat. ceste Stev. ceste  Stev. odseka                    Prometni odsek  \
# 0            AC          A1            30  MP SENTILJ - POCIVALISCE SENTILJ
# 1            AC          A1            30     POCIVALISCE SENTILJ - SENTILJ
# 2            AC          A1           128               PRIKLJ.SENTILJ - MP
# 3            AC          A1            31               SENTILJ  -  PESNICA
# 4            AC          A1            65               PESNICA - DRAGUCOVA
# ...         ...         ...           ...                               ...
# 1167         RT         940          1018                   MATAVUN - VREME
# 1168         RT         940          3214                ZAVRHEK - ARTVIZE-
# 1169         RT         940          3214                ARTVIZE - PREGARJE
# 1170         RT         940          3213                 PREGARJE - HARIJE
# 1171         RT         941          1541                GRABONOS - RADENCI
#
# ...

# %%
data_2013 = pd.read_csv("podatki/improved/2013.csv", sep=";")
data_2013
# Out:
#      Kat. ceste Stev. ceste  Stev. odseka                    Prometni odsek  \
# 0            AC          A1            30  MP SENTILJ - POCIVALISCE SENTILJ
# 1            AC          A1            30     POCIVALISCE SENTILJ - SENTILJ
# 2            AC          A1           128       PRIKLJ.SENTILJ - MP SENTILJ
# 3            AC          A1            31               SENTILJ  -  PESNICA
# 4            AC          A1            65               PESNICA - DRAGUCOVA
# ...         ...         ...           ...                               ...
# 1174         RT         940          1018                   MATAVUN - VREME
# 1175         RT         940          3214                ZAVRHEK - ARTVIZE-
# 1176         RT         940          3214                ARTVIZE - PREGARJE
# 1177         RT         940          3213                 PREGARJE - HARIJE
# 1178         RT         941          1541                GRABONOS - RADENCI
#
# ...

# %%
data_2014 = pd.read_csv("podatki/improved/2014.csv", sep=";")
data_2014
# Out:
#      Kat. ceste Stev. ceste  Stev. odseka                    Prometni odsek  \
# 0            AC          A1            30  MP SENTILJ - POCIVALISCE SENTILJ
# 1            AC          A1            30     POCIVALISCE SENTILJ - SENTILJ
# 2            AC          A1           128       PRIKLJ.SENTILJ - MP SENTILJ
# 3            AC          A1            31               SENTILJ  -  PESNICA
# 4            AC          A1            65               PESNICA - DRAGUCOVA
# ...         ...         ...           ...                               ...
# 1175         RT         940          1018                   MATAVUN - VREME
# 1176         RT         940          3214                ZAVRHEK - ARTVIZE-
# 1177         RT         940          3214                ARTVIZE - PREGARJE
# 1178         RT         940          3213                 PREGARJE - HARIJE
# 1179         RT         941          1541                GRABONOS - RADENCI
#
# ...

# %%
data_2015 = pd.read_csv("podatki/improved/2015.csv", sep=";")
data_2015
# Out:
#      Kat. ceste Stev. ceste  Stev. odseka                    Prometni odsek  \
# 0            AC          A1            30  MP SENTILJ - POCIVALISCE SENTILJ
# 1            AC          A1            30     POCIVALISCE SENTILJ - SENTILJ
# 2            AC          A1           128       PRIKLJ.SENTILJ - MP SENTILJ
# 3            AC          A1            31               SENTILJ  -  PESNICA
# 4            AC          A1            65               PESNICA - DRAGUCOVA
# ...         ...         ...           ...                               ...
# 1177         RT         940          1018                   MATAVUN - VREME
# 1178         RT         940          3214                 ZAVRHEK - ARTVIZE
# 1179         RT         940          3214                ARTVIZE - PREGARJE
# 1180         RT         940          3213                 PREGARJE - HARIJE
# 1181         RT         941          1541                GRABONOS - RADENCI
#
# ...

# %%
data_2016 = pd.read_csv("podatki/improved/2016.csv", sep=";")
data_2016
# Out:
#      Kat. ceste Stev. ceste  Stev. odseka                    Prometni odsek  \
# 0            AC          A1            30  MP SENTILJ - POCIVALISCE SENTILJ
# 1            AC          A1            30     POCIVALISCE SENTILJ - SENTILJ
# 2            AC          A1           128       PRIKLJ.SENTILJ - MP SENTILJ
# 3            AC          A1            31               SENTILJ  -  PESNICA
# 4            AC          A1            65               PESNICA - DRAGUCOVA
# ...         ...         ...           ...                               ...
# 1174         RT         940          1018                   MATAVUN - VREME
# 1175         RT         940          3214                 ZAVRHEK - ARTVIZE
# 1176         RT         940          3214                ARTVIZE - PREGARJE
# 1177         RT         940          3213                 PREGARJE - HARIJE
# 1178         RT         941          1541                GRABONOS - RADENCI
#
# ...

# %%
data_2017 = pd.read_csv("podatki/improved/2017.csv", sep=";")
data_2017
# Out:
#      Kat. ceste Stev. ceste  Stev. odseka                    Prometni odsek  \
# 0            AC          A1            30  MP SENTILJ - POCIVALISCE SENTILJ
# 1            AC          A1            30     POCIVALISCE SENTILJ - SENTILJ
# 2            AC          A1           128       PRIKLJ.SENTILJ - MP SENTILJ
# 3            AC          A1            31               SENTILJ  -  PESNICA
# 4            AC          A1            65               PESNICA - DRAGUCOVA
# ...         ...         ...           ...                               ...
# 1173         RT         940          1018                   MATAVUN - VREME
# 1174         RT         940          3214                 ZAVRHEK - ARTVIZE
# 1175         RT         940          3214                ARTVIZE - PREGARJE
# 1176         RT         940          3213                 PREGARJE - HARIJE
# 1177         RT         941          1541                GRABONOS - RADENCI
#
# ...

# %%
data_2018 = pd.read_csv("podatki/improved/2017.csv", sep=";")
data_2018
# Out:
#      Kat. ceste Stev. ceste  Stev. odseka                    Prometni odsek  \
# 0            AC          A1            30  MP SENTILJ - POCIVALISCE SENTILJ
# 1            AC          A1            30     POCIVALISCE SENTILJ - SENTILJ
# 2            AC          A1           128       PRIKLJ.SENTILJ - MP SENTILJ
# 3            AC          A1            31               SENTILJ  -  PESNICA
# 4            AC          A1            65               PESNICA - DRAGUCOVA
# ...         ...         ...           ...                               ...
# 1173         RT         940          1018                   MATAVUN - VREME
# 1174         RT         940          3214                 ZAVRHEK - ARTVIZE
# 1175         RT         940          3214                ARTVIZE - PREGARJE
# 1176         RT         940          3213                 PREGARJE - HARIJE
# 1177         RT         941          1541                GRABONOS - RADENCI
#
# ...

# %%
data_2019 = pd.read_csv("podatki/improved/2017.csv", sep=";")
data_2019
# Out:
#      Kat. ceste Stev. ceste  Stev. odseka                    Prometni odsek  \
# 0            AC          A1            30  MP SENTILJ - POCIVALISCE SENTILJ
# 1            AC          A1            30     POCIVALISCE SENTILJ - SENTILJ
# 2            AC          A1           128       PRIKLJ.SENTILJ - MP SENTILJ
# 3            AC          A1            31               SENTILJ  -  PESNICA
# 4            AC          A1            65               PESNICA - DRAGUCOVA
# ...         ...         ...           ...                               ...
# 1173         RT         940          1018                   MATAVUN - VREME
# 1174         RT         940          3214                 ZAVRHEK - ARTVIZE
# 1175         RT         940          3214                ARTVIZE - PREGARJE
# 1176         RT         940          3213                 PREGARJE - HARIJE
# 1177         RT         941          1541                GRABONOS - RADENCI
#
# ...

# %%
Numpy2019 = data_2019.to_numpy()
Numpy2019
# Out:
# array([['AC', 'A1', 30, ..., 2.37, 2363, 'PLDP'],
#        ['AC', 'A1', 30, ..., 2.354, 2345, 'PLDP'],
#        ['AC', 'A1', 128, ..., 17.0, 19, 'PLDP'],
#        ...,
#        ['RT', '940', 3214, ..., 1.0, 2, 'PLDP'],
#        ['RT', '940', 3213, ..., 1.0, 4, 'PLDP'],
#        ['RT', '941', 1541, ..., 4.0, 31, 'PLDP']], dtype=object)

# %%
"""Test pull requesta"""
